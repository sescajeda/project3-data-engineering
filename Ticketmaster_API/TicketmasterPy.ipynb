# %% [markdown]
# # TicketmasterPy
#
# ---

# %%
# Dependencies and Setup
#import matplotlib.pyplot as plt
import pandas as pd
#import numpy as np

import requests
import json
from datetime import datetime,timedelta
from pprint import pprint
#from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import ticketmaster_api_key

# Import citipy to determine the cities based on latitude and longitude
#from citipy import citipy

# %%
# Define the base URL and parameters based on the documentation of the Ticketmaster API
base_url = 'https://app.ticketmaster.com/discovery/v2/events?'

params = {'apikey' : ticketmaster_api_key,
          'keyword': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
          'preferredCountry': ["us", " ca"],
          'locale': '*' }

# Make request and store response to be used in and event variable
response = requests.get(base_url, params=params)

events = response.json()

# JSON-ify response
print(json.dumps(events, indent=4))
# Out:
# {
#     "_embedded": {
#         "events": [
#             {
#                 "name": "Shakira - Las Mujeres Ya No Lloran - World Tour",
#                 "type": "event",
#                 "id": "vvG1IZbFSkKfhJ",
#                 "test": false,
#                 "url": "https://www.ticketmaster.com/shakira-las-mujeres-ya-no-lloran-palm-desert-california-11-02-2024/event/0A00608CC64D46E6",
#                 "locale": "en-us",
#                 "images": [
#                     {
#                         "ratio": "4_3",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_CUSTOM.jpg",
#                         "width": 305,
#                         "height": 225,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_EVENT_DETAIL_PAGE_16_9.jpg",
#                         "width": 205,
#                         "height": 115,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "3_2",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_ARTIST_PAGE_3_2.jpg",
#                         "width": 305,
#                         "height": 203,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RECOMENDATION_16_9.jpg",
#                         "width": 100,
#                         "height": 56,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#                         "width": 2048,
#                         "height": 1152,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_16_9.jpg",
#                         "width": 640,
#                         "height": 360,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_16_9.jpg",
#                         "width": 1024,
#                         "height": 576,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_LANDSCAPE_16_9.jpg",
#                         "width": 1136,
#                         "height": 639,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "3_2",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_3_2.jpg",
#                         "width": 1024,
#                         "height": 683,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_SOURCE",
#                         "width": 2426,
#                         "height": 1365,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "3_2",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_3_2.jpg",
#                         "width": 640,
#                         "height": 427,
#                         "fallback": false
#                     }
#                 ],
#                 "sales": {
#                     "public": {
#                         "startDateTime": "2024-04-22T17:00:00Z",
#                         "startTBD": false,
#                         "startTBA": false,
#                         "endDateTime": "2024-11-03T02:30:00Z"
#                     }
#                 },
#                 "dates": {
#                     "start": {
#                         "localDate": "2024-11-02",
#                         "localTime": "19:30:00",
#                         "dateTime": "2024-11-03T02:30:00Z",
#                         "dateTBD": false,
#                         "dateTBA": false,
#                         "timeTBA": false,
#                         "noSpecificTime": false
#                     },
#                     "timezone": "America/Los_Angeles",
#                     "status": {
#                         "code": "cancelled"
#                     },
#                     "spanMultipleDays": false
#                 },
#                 "classifications": [
#                     {
#                         "primary": true,
#                         "segment": {
#                             "id": "KZFzniwnSyZfZ7v7nJ",
#                             "name": "Music"
#                         },
#                         "genre": {
#                             "id": "KnvZfZ7vAev",
#                             "name": "Pop"
#                         },
#                         "subGenre": {
#                             "id": "KZazBEonSMnZfZ7vk1t",
#                             "name": "Pop"
#                         },
#                         "type": {
#                             "id": "KZAyXgnZfZ7v7nI",
#                             "name": "Undefined"
#                         },
#                         "subType": {
#                             "id": "KZFzBErXgnZfZ7v7lJ",
#                             "name": "Undefined"
#                         },
#                         "family": false
#                     }
#                 ],
#                 "promoter": {
#                     "id": "653",
#                     "name": "LIVE NATION MUSIC",
#                     "description": "LIVE NATION MUSIC / NTL / USA"
#                 },
#                 "promoters": [
#                     {
#                         "id": "653",
#                         "name": "LIVE NATION MUSIC",
#                         "description": "LIVE NATION MUSIC / NTL / USA"
#                     }
#                 ],
#                 "pleaseNote": "Unfortunately, the Event Organizer has had to cancel your event. You don't need to do a thing. We'll issue a refund to the original method of payment used at time of purchase, as soon as funds are received from the Event Organizer. It should appear on your account within 14-21 days. Please Note: If the tickets were transferred to you, the refund will go to the fan who originally purchased the tickets from Ticketmaster. Please see our Purchase Policy for more information.",
#                 "priceRanges": [
#                     {
#                         "type": "standard",
#                         "currency": "USD",
#                         "min": 201.5,
#                         "max": 564.75
#                     }
#                 ],
#                 "products": [
#                     {
#                         "name": "PARKWHIZ ACRISURE ARENA AT GREATER PALM SPRINGS",
#                         "id": "vvG1IZbFTqLN_D",
#                         "url": "https://www.ticketmaster.com/parkwhiz-acrisure-arena-at-greater-palm-palm-desert-california-11-02-2024/event/0A00608FDD7E367B",
#                         "type": "Upsell",
#                         "classifications": [
#                             {
#                                 "primary": true,
#                                 "segment": {
#                                     "id": "KZFzniwnSyZfZ7v7n1",
#                                     "name": "Miscellaneous"
#                                 },
#                                 "genre": {
#                                     "id": "KnvZfZ7v7ll",
#                                     "name": "Undefined"
#                                 },
#                                 "subGenre": {
#                                     "id": "KZazBEonSMnZfZ7vAv1",
#                                     "name": "Undefined"
#                                 },
#                                 "type": {
#                                     "id": "KZAyXgnZfZ7vAva",
#                                     "name": "Parking"
#                                 },
#                                 "subType": {
#                                     "id": "KZFzBErXgnZfZ7vAFe",
#                                     "name": "Regular"
#                                 },
#                                 "family": false
#                             }
#                         ]
#                     }
#                 ],
#                 "seatmap": {
#                     "staticUrl": "https://mapsapi.tmol.io/maps/geometry/3/event/0A00608CC64D46E6/staticImage?type=png&systemId=HOST",
#                     "id": "seatmap"
#                 },
#                 "accessibility": {
#                     "ticketLimit": 4,
#                     "id": "accessibility"
#                 },
#                 "ticketLimit": {
#                     "info": "There is an overall 6 ticket limit for this event.",
#                     "id": "ticketLimit"
#                 },
#                 "ageRestrictions": {
#                     "legalAgeEnforced": false,
#                     "id": "ageRestrictions"
#                 },
#                 "ticketing": {
#                     "safeTix": {
#                         "enabled": true,
#                         "inAppOnlyEnabled": false
#                     },
#                     "allInclusivePricing": {
#                         "enabled": true
#                     },
#                     "id": "ticketing"
#                 },
#                 "_links": {
#                     "self": {
#                         "href": "/discovery/v2/events/vvG1IZbFSkKfhJ?locale=en-us"
#                     },
#                     "attractions": [
#                         {
#                             "href": "/discovery/v2/attractions/K8vZ9171xeV?locale=en-us"
#                         }
#                     ],
#                     "venues": [
#                         {
#                             "href": "/discovery/v2/venues/KovZ917A-Tn?locale=en-us"
#                         }
#                     ]
#                 },
#                 "_embedded": {
#                     "venues": [
#                         {
#                             "name": "Acrisure Arena at Greater Palm Springs",
#                             "type": "venue",
#                             "id": "KovZ917A-Tn",
#                             "test": false,
#                             "url": "https://www.ticketmaster.com/acrisure-arena-at-greater-palm-springs-tickets-palm-desert/venue/82821",
#                             "locale": "en-us",
#                             "images": [
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dbimages/22674v.jpg",
#                                     "width": 205,
#                                     "height": 115,
#                                     "fallback": false
#                                 }
#                             ],
#                             "postalCode": "92211",
#                             "timezone": "America/Los_Angeles",
#                             "city": {
#                                 "name": "Palm Desert"
#                             },
#                             "state": {
#                                 "name": "California",
#                                 "stateCode": "CA"
#                             },
#                             "country": {
#                                 "name": "United States Of America",
#                                 "countryCode": "US"
#                             },
#                             "address": {
#                                 "line1": "75702 Varner Rd."
#                             },
#                             "location": {
#                                 "longitude": "-116.542747",
#                                 "latitude": "33.825315"
#                             },
#                             "markets": [
#                                 {
#                                     "name": "Los Angeles",
#                                     "id": "27"
#                                 }
#                             ],
#                             "dmas": [
#                                 {
#                                     "id": 223
#                                 },
#                                 {
#                                     "id": 324
#                                 },
#                                 {
#                                     "id": 354
#                                 },
#                                 {
#                                     "id": 383
#                                 }
#                             ],
#                             "boxOfficeInfo": {
#                                 "phoneNumberDetail": "760 835 5100"
#                             },
#                             "upcomingEvents": {
#                                 "ticketmaster": 92,
#                                 "_total": 92,
#                                 "_filtered": 0
#                             },
#                             "_links": {
#                                 "self": {
#                                     "href": "/discovery/v2/venues/KovZ917A-Tn?locale=en-us"
#                                 }
#                             }
#                         }
#                     ],
#                     "attractions": [
#                         {
#                             "name": "Shakira",
#                             "type": "attraction",
#                             "id": "K8vZ9171xeV",
#                             "test": false,
#                             "url": "https://www.ticketmaster.com.au/shakira-tickets/artist/779049",
#                             "locale": "en-us",
#                             "externalLinks": {
#                                 "youtube": [
#                                     {
#                                         "url": "https://www.youtube.com/user/shakira"
#                                     }
#                                 ],
#                                 "twitter": [
#                                     {
#                                         "url": "https://twitter.com/shakira"
#                                     }
#                                 ],
#                                 "itunes": [
#                                     {
#                                         "url": "https://itunes.apple.com/artist/id889327"
#                                     }
#                                 ],
#                                 "lastfm": [
#                                     {
#                                         "url": "https://www.last.fm/music/Shakira"
#                                     }
#                                 ],
#                                 "spotify": [
#                                     {
#                                         "url": "https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp"
#                                     }
#                                 ],
#                                 "facebook": [
#                                     {
#                                         "url": "https://www.facebook.com/shakira"
#                                     }
#                                 ],
#                                 "musicbrainz": [
#                                     {
#                                         "id": "bf24ca37-25f4-4e34-9aec-460b94364cfc",
#                                         "url": "https://musicbrainz.org/artist/bf24ca37-25f4-4e34-9aec-460b94364cfc"
#                                     }
#                                 ],
#                                 "instagram": [
#                                     {
#                                         "url": "https://instagram.com/shakira"
#                                     }
#                                 ],
#                                 "homepage": [
#                                     {
#                                         "url": "http://www.shakira-online.de/"
#                                     }
#                                 ]
#                             },
#                             "aliases": [
#                                 "sakira",
#                                 "shakira",
#                                 "shakira concert",
#                                 "shakria",
#                                 "sharika",
#                                 "sharkira",
#                                 "shikira",
#                                 "skakira"
#                             ],
#                             "images": [
#                                 {
#                                     "ratio": "4_3",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_CUSTOM.jpg",
#                                     "width": 305,
#                                     "height": 225,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_EVENT_DETAIL_PAGE_16_9.jpg",
#                                     "width": 205,
#                                     "height": 115,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "3_2",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_ARTIST_PAGE_3_2.jpg",
#                                     "width": 305,
#                                     "height": 203,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RECOMENDATION_16_9.jpg",
#                                     "width": 100,
#                                     "height": 56,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#                                     "width": 2048,
#                                     "height": 1152,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_16_9.jpg",
#                                     "width": 640,
#                                     "height": 360,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_16_9.jpg",
#                                     "width": 1024,
#                                     "height": 576,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_LANDSCAPE_16_9.jpg",
#                                     "width": 1136,
#                                     "height": 639,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "3_2",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_3_2.jpg",
#                                     "width": 1024,
#                                     "height": 683,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_SOURCE",
#                                     "width": 2426,
#                                     "height": 1365,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "3_2",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_3_2.jpg",
#                                     "width": 640,
#                                     "height": 427,
#                                     "fallback": false
#                                 }
#                             ],
#                             "classifications": [
#                                 {
#                                     "primary": true,
#                                     "segment": {
#                                         "id": "KZFzniwnSyZfZ7v7nJ",
#                                         "name": "Music"
#                                     },
#                                     "genre": {
#                                         "id": "KnvZfZ7vAev",
#                                         "name": "Pop"
#                                     },
#                                     "subGenre": {
#                                         "id": "KZazBEonSMnZfZ7vk1t",
#                                         "name": "Pop"
#                                     },
#                                     "type": {
#                                         "id": "KZAyXgnZfZ7v7la",
#                                         "name": "Individual"
#                                     },
#                                     "subType": {
#                                         "id": "KZFzBErXgnZfZ7vAde",
#                                         "name": "Singer/Vocalist"
#                                     },
#                                     "family": false
#                                 }
#                             ],
#                             "upcomingEvents": {
#                                 "ticketmaster": 27,
#                                 "_total": 27,
#                                 "_filtered": 0
#                             },
#                             "_links": {
#                                 "self": {
#                                     "href": "/discovery/v2/attractions/K8vZ9171xeV?locale=en-us"
#                                 }
#                             }
#                         }
#                     ]
#                 }
#             },
#             {
#                 "name": "Shakira - Las Mujeres Ya No Lloran - World Tour",
#                 "type": "event",
#                 "id": "vvG1IZbFTpcNCA",
#                 "test": false,
#                 "url": "https://www.ticketmaster.com/shakira-las-mujeres-ya-no-lloran-palm-desert-california-11-03-2024/event/0A00608FD6B63385",
#                 "locale": "en-us",
#                 "images": [
#                     {
#                         "ratio": "4_3",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_CUSTOM.jpg",
#                         "width": 305,
#                         "height": 225,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_EVENT_DETAIL_PAGE_16_9.jpg",
#                         "width": 205,
#                         "height": 115,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "3_2",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_ARTIST_PAGE_3_2.jpg",
#                         "width": 305,
#                         "height": 203,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RECOMENDATION_16_9.jpg",
#                         "width": 100,
#                         "height": 56,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#                         "width": 2048,
#                         "height": 1152,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_16_9.jpg",
#                         "width": 640,
#                         "height": 360,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_16_9.jpg",
#                         "width": 1024,
#                         "height": 576,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_LANDSCAPE_16_9.jpg",
#                         "width": 1136,
#                         "height": 639,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "3_2",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_3_2.jpg",
#                         "width": 1024,
#                         "height": 683,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_SOURCE",
#                         "width": 2426,
#                         "height": 1365,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "3_2",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_3_2.jpg",
#                         "width": 640,
#                         "height": 427,
#                         "fallback": false
#                     }
#                 ],
#                 "sales": {
#                     "public": {
#                         "startDateTime": "2024-04-22T17:00:00Z",
#                         "startTBD": false,
#                         "startTBA": false,
#                         "endDateTime": "2024-11-04T03:30:00Z"
#                     }
#                 },
#                 "dates": {
#                     "start": {
#                         "localDate": "2024-11-03",
#                         "localTime": "19:30:00",
#                         "dateTime": "2024-11-04T03:30:00Z",
#                         "dateTBD": false,
#                         "dateTBA": false,
#                         "timeTBA": false,
#                         "noSpecificTime": false
#                     },
#                     "timezone": "America/Los_Angeles",
#                     "status": {
#                         "code": "cancelled"
#                     },
#                     "spanMultipleDays": false
#                 },
#                 "classifications": [
#                     {
#                         "primary": true,
#                         "segment": {
#                             "id": "KZFzniwnSyZfZ7v7nJ",
#                             "name": "Music"
#                         },
#                         "genre": {
#                             "id": "KnvZfZ7vAev",
#                             "name": "Pop"
#                         },
#                         "subGenre": {
#                             "id": "KZazBEonSMnZfZ7vk1t",
#                             "name": "Pop"
#                         },
#                         "type": {
#                             "id": "KZAyXgnZfZ7v7nI",
#                             "name": "Undefined"
#                         },
#                         "subType": {
#                             "id": "KZFzBErXgnZfZ7v7lJ",
#                             "name": "Undefined"
#                         },
#                         "family": false
#                     }
#                 ],
#                 "promoter": {
#                     "id": "653",
#                     "name": "LIVE NATION MUSIC",
#                     "description": "LIVE NATION MUSIC / NTL / USA"
#                 },
#                 "promoters": [
#                     {
#                         "id": "653",
#                         "name": "LIVE NATION MUSIC",
#                         "description": "LIVE NATION MUSIC / NTL / USA"
#                     }
#                 ],
#                 "pleaseNote": "Unfortunately, the Event Organizer has had to cancel your event. You don't need to do a thing. We'll issue a refund to the original method of payment used at time of purchase, as soon as funds are received from the Event Organizer. It should appear on your account within 14-21 days. Please Note: If the tickets were transferred to you, the refund will go to the fan who originally purchased the tickets from Ticketmaster. Please see our Purchase Policy for more information.",
#                 "priceRanges": [
#                     {
#                         "type": "standard",
#                         "currency": "USD",
#                         "min": 201.5,
#                         "max": 564.75
#                     }
#                 ],
#                 "products": [
#                     {
#                         "name": "PARKWHIZ ACRISURE ARENA AT GREATER PALM SPRINGS",
#                         "id": "vvG1IZbavUsZB2",
#                         "url": "https://www.ticketmaster.com/parkwhiz-acrisure-arena-at-greater-palm-palm-desert-california-11-03-2024/event/0A00609076C40E8F",
#                         "type": "Upsell",
#                         "classifications": [
#                             {
#                                 "primary": true,
#                                 "segment": {
#                                     "id": "KZFzniwnSyZfZ7v7n1",
#                                     "name": "Miscellaneous"
#                                 },
#                                 "genre": {
#                                     "id": "KnvZfZ7v7ll",
#                                     "name": "Undefined"
#                                 },
#                                 "subGenre": {
#                                     "id": "KZazBEonSMnZfZ7vAv1",
#                                     "name": "Undefined"
#                                 },
#                                 "type": {
#                                     "id": "KZAyXgnZfZ7vAva",
#                                     "name": "Parking"
#                                 },
#                                 "subType": {
#                                     "id": "KZFzBErXgnZfZ7vAFe",
#                                     "name": "Regular"
#                                 },
#                                 "family": false
#                             }
#                         ]
#                     }
#                 ],
#                 "seatmap": {
#                     "staticUrl": "https://mapsapi.tmol.io/maps/geometry/3/event/0A00608FD6B63385/staticImage?type=png&systemId=HOST",
#                     "id": "seatmap"
#                 },
#                 "accessibility": {
#                     "ticketLimit": 4,
#                     "id": "accessibility"
#                 },
#                 "ticketLimit": {
#                     "info": "There is an overall 6 ticket limit for this event.",
#                     "id": "ticketLimit"
#                 },
#                 "ageRestrictions": {
#                     "legalAgeEnforced": false,
#                     "id": "ageRestrictions"
#                 },
#                 "ticketing": {
#                     "safeTix": {
#                         "enabled": true,
#                         "inAppOnlyEnabled": false
#                     },
#                     "allInclusivePricing": {
#                         "enabled": true
#                     },
#                     "id": "ticketing"
#                 },
#                 "_links": {
#                     "self": {
#                         "href": "/discovery/v2/events/vvG1IZbFTpcNCA?locale=en-us"
#                     },
#                     "attractions": [
#                         {
#                             "href": "/discovery/v2/attractions/K8vZ9171xeV?locale=en-us"
#                         }
#                     ],
#                     "venues": [
#                         {
#                             "href": "/discovery/v2/venues/KovZ917A-Tn?locale=en-us"
#                         }
#                     ]
#                 },
#                 "_embedded": {
#                     "venues": [
#                         {
#                             "name": "Acrisure Arena at Greater Palm Springs",
#                             "type": "venue",
#                             "id": "KovZ917A-Tn",
#                             "test": false,
#                             "url": "https://www.ticketmaster.com/acrisure-arena-at-greater-palm-springs-tickets-palm-desert/venue/82821",
#                             "locale": "en-us",
#                             "images": [
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dbimages/22674v.jpg",
#                                     "width": 205,
#                                     "height": 115,
#                                     "fallback": false
#                                 }
#                             ],
#                             "postalCode": "92211",
#                             "timezone": "America/Los_Angeles",
#                             "city": {
#                                 "name": "Palm Desert"
#                             },
#                             "state": {
#                                 "name": "California",
#                                 "stateCode": "CA"
#                             },
#                             "country": {
#                                 "name": "United States Of America",
#                                 "countryCode": "US"
#                             },
#                             "address": {
#                                 "line1": "75702 Varner Rd."
#                             },
#                             "location": {
#                                 "longitude": "-116.542747",
#                                 "latitude": "33.825315"
#                             },
#                             "markets": [
#                                 {
#                                     "name": "Los Angeles",
#                                     "id": "27"
#                                 }
#                             ],
#                             "dmas": [
#                                 {
#                                     "id": 223
#                                 },
#                                 {
#                                     "id": 324
#                                 },
#                                 {
#                                     "id": 354
#                                 },
#                                 {
#                                     "id": 383
#                                 }
#                             ],
#                             "boxOfficeInfo": {
#                                 "phoneNumberDetail": "760 835 5100"
#                             },
#                             "upcomingEvents": {
#                                 "ticketmaster": 92,
#                                 "_total": 92,
#                                 "_filtered": 0
#                             },
#                             "_links": {
#                                 "self": {
#                                     "href": "/discovery/v2/venues/KovZ917A-Tn?locale=en-us"
#                                 }
#                             }
#                         }
#                     ],
#                     "attractions": [
#                         {
#                             "name": "Shakira",
#                             "type": "attraction",
#                             "id": "K8vZ9171xeV",
#                             "test": false,
#                             "url": "https://www.ticketmaster.com.au/shakira-tickets/artist/779049",
#                             "locale": "en-us",
#                             "externalLinks": {
#                                 "youtube": [
#                                     {
#                                         "url": "https://www.youtube.com/user/shakira"
#                                     }
#                                 ],
#                                 "twitter": [
#                                     {
#                                         "url": "https://twitter.com/shakira"
#                                     }
#                                 ],
#                                 "itunes": [
#                                     {
#                                         "url": "https://itunes.apple.com/artist/id889327"
#                                     }
#                                 ],
#                                 "lastfm": [
#                                     {
#                                         "url": "https://www.last.fm/music/Shakira"
#                                     }
#                                 ],
#                                 "spotify": [
#                                     {
#                                         "url": "https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp"
#                                     }
#                                 ],
#                                 "facebook": [
#                                     {
#                                         "url": "https://www.facebook.com/shakira"
#                                     }
#                                 ],
#                                 "musicbrainz": [
#                                     {
#                                         "id": "bf24ca37-25f4-4e34-9aec-460b94364cfc",
#                                         "url": "https://musicbrainz.org/artist/bf24ca37-25f4-4e34-9aec-460b94364cfc"
#                                     }
#                                 ],
#                                 "instagram": [
#                                     {
#                                         "url": "https://instagram.com/shakira"
#                                     }
#                                 ],
#                                 "homepage": [
#                                     {
#                                         "url": "http://www.shakira-online.de/"
#                                     }
#                                 ]
#                             },
#                             "aliases": [
#                                 "sakira",
#                                 "shakira",
#                                 "shakira concert",
#                                 "shakria",
#                                 "sharika",
#                                 "sharkira",
#                                 "shikira",
#                                 "skakira"
#                             ],
#                             "images": [
#                                 {
#                                     "ratio": "4_3",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_CUSTOM.jpg",
#                                     "width": 305,
#                                     "height": 225,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_EVENT_DETAIL_PAGE_16_9.jpg",
#                                     "width": 205,
#                                     "height": 115,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "3_2",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_ARTIST_PAGE_3_2.jpg",
#                                     "width": 305,
#                                     "height": 203,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RECOMENDATION_16_9.jpg",
#                                     "width": 100,
#                                     "height": 56,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#                                     "width": 2048,
#                                     "height": 1152,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_16_9.jpg",
#                                     "width": 640,
#                                     "height": 360,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_16_9.jpg",
#                                     "width": 1024,
#                                     "height": 576,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_LANDSCAPE_16_9.jpg",
#                                     "width": 1136,
#                                     "height": 639,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "3_2",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_3_2.jpg",
#                                     "width": 1024,
#                                     "height": 683,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_SOURCE",
#                                     "width": 2426,
#                                     "height": 1365,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "3_2",
#                                     "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_3_2.jpg",
#                                     "width": 640,
#                                     "height": 427,
#                                     "fallback": false
#                                 }
#                             ],
#                             "classifications": [
#                                 {
#                                     "primary": true,
#                                     "segment": {
#                                         "id": "KZFzniwnSyZfZ7v7nJ",
#                                         "name": "Music"
#                                     },
#                                     "genre": {
#                                         "id": "KnvZfZ7vAev",
#                                         "name": "Pop"
#                                     },
#                                     "subGenre": {
#                                         "id": "KZazBEonSMnZfZ7vk1t",
#                                         "name": "Pop"
#                                     },
#                                     "type": {
#                                         "id": "KZAyXgnZfZ7v7la",
#                                         "name": "Individual"
#                                     },
#                                     "subType": {
#                                         "id": "KZFzBErXgnZfZ7vAde",
#                                         "name": "Singer/Vocalist"
#                                     },
#                                     "family": false
#                                 }
#                             ],
#                             "upcomingEvents": {
#                                 "ticketmaster": 27,
#                                 "_total": 27,
#                                 "_filtered": 0
#                             },
#                             "_links": {
#                                 "self": {
#                                     "href": "/discovery/v2/attractions/K8vZ9171xeV?locale=en-us"
#                                 }
#                             }
#                         }
#                     ]
#                 }
#             },
#             {
#                 "name": "Shakira - Las Mujeres Ya No Lloran - World Tour",
#                 "type": "event",
#                 "id": "vv170ZbFGkMDd4OB",
#                 "test": false,
#                 "url": "https://www.ticketmaster.com/shakira-las-mujeres-ya-no-lloran-inglewood-california-11-09-2024/event/0900608DFB0D583A",
#                 "locale": "en-us",
#                 "images": [
#                     {
#                         "ratio": "4_3",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_CUSTOM.jpg",
#                         "width": 305,
#                         "height": 225,
#                         "fallback": false
#                     },
#                     {
#                         "ratio": "16_9",
#                         "url": "https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_EVENT_DETAIL_PAGE_16_9.jpg",
#                         "width": 205,
#                         "height": 115,
#                         "fallback": false
#                     },
#                     {
# ...
#                 "ageRestrictions": {
#                     "legalAgeEnforced": false,
#                     "id": "ageRestrictions"
#                 },
#                 "ticketing": {
#                     "safeTix": {
#                         "enabled": true,
#                         "inAppOnlyEnabled": false
#                     },
#                     "allInclusivePricing": {
#                         "enabled": false
#                     },
#                     "id": "ticketing"
#                 },
#                 "_links": {
#                     "self": {
#                         "href": "/discovery/v2/events/1kAZv-AIGA5q8JQ?locale=en-us"
#                     },
#                     "attractions": [
#                         {
#                             "href": "/discovery/v2/attractions/K8vZ9171xeV?locale=en-us"
#                         }
#                     ],
#                     "venues": [
#                         {
#                             "href": "/discovery/v2/venues/KovZpZAd1IaA?locale=en-us"
#                         }
#                     ]
#                 },
#                 "_embedded": {
#                     "venues": [
#                         {
#                             "name": "Estadio GNP Seguros",
#                             "type": "venue",
#                             "id": "KovZpZAd1IaA",
#                             "test": false,
#                             "url": "https://www.ticketmaster.com.mx/estadio-gnp-seguros-tickets-cdmx/venue/163903",
#                             "locale": "en-us",
#                             "postalCode": "08400",
#                             "timezone": "America/Mexico_City",
#                             "city": {
#                                 "name": "Cdmx"
#                             },
#                             "state": {
#                                 "name": "Ciudad de M\u00e9xico",
#                                 "stateCode": "DF"
#                             },
#                             "country": {
#                                 "name": "Mexico",
#                                 "countryCode": "MX"
#                             },
#                             "address": {
#                                 "line1": "Viaducto Piedad y R\u00edo Churubusco s/n Cd. Deportiva"
#                             },
#                             "location": {
#                                 "longitude": "-99.095618",
#                                 "latitude": "19.405199"
#                             },
#                             "markets": [
#                                 {
#                                     "name": "All of Mexico",
#                                     "id": "401"
#                                 },
#                                 {
#                                     "name": "Mexico City and Metropolitan Area",
#                                     "id": "402"
#                                 }
#                             ],
#                             "dmas": [
#                                 {
#                                     "id": 801
#                                 },
#                                 {
#                                     "id": 802
#                                 }
#                             ],
#                             "boxOfficeInfo": {
#                                 "phoneNumberDetail": "(55) 52379999 ext. 71008",
#                                 "openHoursDetail": "Solo dia del evento",
#                                 "acceptedPaymentDetail": "Efectivo,Tarjeta de Credito y Debito",
#                                 "willCallDetail": "CONCIERTOS : El dia del evento en la taquilla de Puerta 5 de Ciudad Deportiva en Horario de 10:00 hasta 45 minutos despues de iniciado el evento."
#                             },
#                             "parkingDetail": "Dentro de la Cd. Deportiva Esta a la venta Unicamente por Centros Ticketmaster y Taquilla Para conciertos acceso por puerta 7, 8 y 9 de Ciudad Deportiva.",
#                             "accessibleSeatingDetail": "Los boletos se pueden adquirir tanto en el 53259000 como en taquillas Conciertos: Se tiene un area asignada especial a nivel pista para dar el servicio.",
#                             "generalInfo": {
#                                 "generalRule": "No se permite el acceso con camaras de video, camaras fotograficas profesionales, alimentos y bebidas, mascotas, armas, paraguas, mochilas.",
#                                 "childRule": "Dependiendo del evento ni\ufffdos pagan a partir de 3 a\ufffdos."
#                             },
#                             "upcomingEvents": {
#                                 "archtics": 12,
#                                 "ticketmaster": 54,
#                                 "_total": 66,
#                                 "_filtered": 0
#                             },
#                             "ada": {
#                                 "adaPhones": "Questions or comments contactanos@ticketmaster.com.mx",
#                                 "adaCustomCopy": "INFORMATION",
#                                 "adaHours": "Monday to Friday 8am-10pm, Saturday 9am-9pm, Sunday and Holidays 10am-7pm"
#                             },
#                             "_links": {
#                                 "self": {
#                                     "href": "/discovery/v2/venues/KovZpZAd1IaA?locale=en-us"
#                                 }
#                             }
#                         }
#                     ],
#                     "attractions": [
#                         {
#                             "name": "Shakira",
#                             "type": "attraction",
#                             "id": "K8vZ9171xeV",
#                             "test": false,
#                             "url": "https://www.ticketmaster.com.au/shakira-tickets/artist/779049",
#                             "locale": "en-us",
#                             "externalLinks": {
#                                 "youtube": [
#                                     {
#                                         "url": "https://www.youtube.com/user/shakira"
#                                     }
#                                 ],
#                                 "twitter": [
#                                     {
#                                         "url": "https://twitter.com/shakira"
#                                     }
#                                 ],
#                                 "itunes": [
#                                     {
#                                         "url": "https://itunes.apple.com/artist/id889327"
#                                     }
#                                 ],
#                                 "lastfm": [
#                                     {
#                                         "url": "https://www.last.fm/music/Shakira"
#                                     }
#                                 ],
#                                 "spotify": [
#                                     {
#                                         "url": "https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp"
#                                     }
#                                 ],
#                                 "facebook": [
#                                     {
#                                         "url": "https://www.facebook.com/shakira"
#                                     }
#                                 ],
#                                 "musicbrainz": [
#                                     {
#                                         "id": "bf24ca37-25f4-4e34-9aec-460b94364cfc",
#                                         "url": "https://musicbrainz.org/artist/bf24ca37-25f4-4e34-9aec-460b94364cfc"
#                                     }
#                                 ],
#                                 "instagram": [
#                                     {
#                                         "url": "https://instagram.com/shakira"
#                                     }
#                                 ],
#                                 "homepage": [
#                                     {
#                                         "url": "http://www.shakira-online.de/"
#                                     }
#                                 ]
#                             },
#                             "aliases": [
#                                 "sakira",
#                                 "shakira",
#                                 "shakira concert",
#                                 "shakria",
#                                 "sharika",
#                                 "sharkira",
#                                 "shikira",
#                                 "skakira"
#                             ],
#                             "images": [
#                                 {
#                                     "ratio": "3_2",
#                                     "url": "https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_TABLET_LANDSCAPE_3_2.jpg",
#                                     "width": 1024,
#                                     "height": 683,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_RETINA_LANDSCAPE_16_9.jpg",
#                                     "width": 1136,
#                                     "height": 639,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_TABLET_LANDSCAPE_16_9.jpg",
#                                     "width": 1024,
#                                     "height": 576,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_SOURCE",
#                                     "width": 2426,
#                                     "height": 1365,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "3_2",
#                                     "url": "https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_RETINA_PORTRAIT_3_2.jpg",
#                                     "width": 640,
#                                     "height": 427,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "3_2",
#                                     "url": "https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_ARTIST_PAGE_3_2.jpg",
#                                     "width": 305,
#                                     "height": 203,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_RETINA_PORTRAIT_16_9.jpg",
#                                     "width": 640,
#                                     "height": 360,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_RECOMENDATION_16_9.jpg",
#                                     "width": 100,
#                                     "height": 56,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_EVENT_DETAIL_PAGE_16_9.jpg",
#                                     "width": 205,
#                                     "height": 115,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "16_9",
#                                     "url": "https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#                                     "width": 2048,
#                                     "height": 1152,
#                                     "fallback": false
#                                 },
#                                 {
#                                     "ratio": "4_3",
#                                     "url": "https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_CUSTOM.jpg",
#                                     "width": 305,
#                                     "height": 225,
#                                     "fallback": false
#                                 }
#                             ],
#                             "classifications": [
#                                 {
#                                     "primary": true,
#                                     "segment": {
#                                         "id": "KZFzniwnSyZfZ7v7nJ",
#                                         "name": "Music"
#                                     },
#                                     "genre": {
#                                         "id": "KnvZfZ7vAev",
#                                         "name": "Pop"
#                                     },
#                                     "subGenre": {
#                                         "id": "KZazBEonSMnZfZ7vk1t",
#                                         "name": "Pop"
#                                     },
#                                     "type": {
#                                         "id": "KZAyXgnZfZ7v7la",
#                                         "name": "Individual"
#                                     },
#                                     "subType": {
#                                         "id": "KZFzBErXgnZfZ7vAde",
#                                         "name": "Singer/Vocalist"
#                                     },
#                                     "family": false
#                                 }
#                             ],
#                             "upcomingEvents": {
#                                 "ticketmaster": 27,
#                                 "_total": 27,
#                                 "_filtered": 0
#                             },
#                             "_links": {
#                                 "self": {
#                                     "href": "/discovery/v2/attractions/K8vZ9171xeV?locale=en-us"
#                                 }
#                             }
#                         }
#                     ]
#                 }
#             }
#         ]
#     },
#     "_links": {
#         "first": {
#             "href": "/discovery/v2/events?preferredCountry=us%2C+ca&locale=*&keyword=Shakira+-+Las+Mujeres+Ya+No+Lloran+-+World+Tour&page=0&size=20"
#         },
#         "self": {
#             "href": "/discovery/v2/events?preferredCountry=us%2C+ca&locale=*&keyword=Shakira+-+Las+Mujeres+Ya+No+Lloran+-+World+Tour"
#         },
#         "next": {
#             "href": "/discovery/v2/events?preferredCountry=us%2C+ca&locale=*&keyword=Shakira+-+Las+Mujeres+Ya+No+Lloran+-+World+Tour&page=1&size=20"
#         },
#         "last": {
#             "href": "/discovery/v2/events?preferredCountry=us%2C+ca&locale=*&keyword=Shakira+-+Las+Mujeres+Ya+No+Lloran+-+World+Tour&page=2&size=20"
#         }
#     },
#     "page": {
#         "size": 20,
#         "totalElements": 45,
#         "totalPages": 3,
#         "number": 0
#     }
# }

# %%
# Get to the dictionary that cotains the concerts information
concerts = events['_embedded']['events']
pprint(concerts)
# Out:
# [{'_embedded': {'attractions': [{'_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9171xeV?locale=en-us'}},
#                                  'aliases': ['sakira',
#                                              'shakira',
#                                              'shakira concert',
#                                              'shakria',
#                                              'sharika',
#                                              'sharkira',
#                                              'shikira',
#                                              'skakira'],
#                                  'classifications': [{'family': False,
#                                                       'genre': {'id': 'KnvZfZ7vAev',
#                                                                 'name': 'Pop'},
#                                                       'primary': True,
#                                                       'segment': {'id': 'KZFzniwnSyZfZ7v7nJ',
#                                                                   'name': 'Music'},
#                                                       'subGenre': {'id': 'KZazBEonSMnZfZ7vk1t',
#                                                                    'name': 'Pop'},
#                                                       'subType': {'id': 'KZFzBErXgnZfZ7vAde',
#                                                                   'name': 'Singer/Vocalist'},
#                                                       'type': {'id': 'KZAyXgnZfZ7v7la',
#                                                                'name': 'Individual'}}],
#                                  'externalLinks': {'facebook': [{'url': 'https://www.facebook.com/shakira'}],
#                                                    'homepage': [{'url': 'http://www.shakira-online.de/'}],
#                                                    'instagram': [{'url': 'https://instagram.com/shakira'}],
#                                                    'itunes': [{'url': 'https://itunes.apple.com/artist/id889327'}],
#                                                    'lastfm': [{'url': 'https://www.last.fm/music/Shakira'}],
#                                                    'musicbrainz': [{'id': 'bf24ca37-25f4-4e34-9aec-460b94364cfc',
#                                                                     'url': 'https://musicbrainz.org/artist/bf24ca37-25f4-4e34-9aec-460b94364cfc'}],
#                                                    'spotify': [{'url': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'}],
#                                                    'twitter': [{'url': 'https://twitter.com/shakira'}],
#                                                    'youtube': [{'url': 'https://www.youtube.com/user/shakira'}]},
#                                  'id': 'K8vZ9171xeV',
#                                  'images': [{'fallback': False,
#                                              'height': 225,
#                                              'ratio': '4_3',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_CUSTOM.jpg',
#                                              'width': 305},
#                                             {'fallback': False,
#                                              'height': 115,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_EVENT_DETAIL_PAGE_16_9.jpg',
#                                              'width': 205},
#                                             {'fallback': False,
#                                              'height': 203,
#                                              'ratio': '3_2',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_ARTIST_PAGE_3_2.jpg',
#                                              'width': 305},
#                                             {'fallback': False,
#                                              'height': 56,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RECOMENDATION_16_9.jpg',
#                                              'width': 100},
#                                             {'fallback': False,
#                                              'height': 1152,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#                                              'width': 2048},
#                                             {'fallback': False,
#                                              'height': 360,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_16_9.jpg',
#                                              'width': 640},
#                                             {'fallback': False,
#                                              'height': 576,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_16_9.jpg',
#                                              'width': 1024},
#                                             {'fallback': False,
#                                              'height': 639,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_LANDSCAPE_16_9.jpg',
#                                              'width': 1136},
#                                             {'fallback': False,
#                                              'height': 683,
#                                              'ratio': '3_2',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_3_2.jpg',
#                                              'width': 1024},
#                                             {'fallback': False,
#                                              'height': 1365,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_SOURCE',
#                                              'width': 2426},
#                                             {'fallback': False,
#                                              'height': 427,
#                                              'ratio': '3_2',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_3_2.jpg',
#                                              'width': 640}],
#                                  'locale': 'en-us',
#                                  'name': 'Shakira',
#                                  'test': False,
#                                  'type': 'attraction',
#                                  'upcomingEvents': {'_filtered': 0,
#                                                     '_total': 27,
#                                                     'ticketmaster': 27},
#                                  'url': 'https://www.ticketmaster.com.au/shakira-tickets/artist/779049'}],
#                 'venues': [{'_links': {'self': {'href': '/discovery/v2/venues/KovZ917A-Tn?locale=en-us'}},
#                             'address': {'line1': '75702 Varner Rd.'},
#                             'boxOfficeInfo': {'phoneNumberDetail': '760 835 '
#                                                                    '5100'},
#                             'city': {'name': 'Palm Desert'},
#                             'country': {'countryCode': 'US',
#                                         'name': 'United States Of America'},
#                             'dmas': [{'id': 223},
#                                      {'id': 324},
#                                      {'id': 354},
#                                      {'id': 383}],
#                             'id': 'KovZ917A-Tn',
#                             'images': [{'fallback': False,
#                                         'height': 115,
#                                         'ratio': '16_9',
#                                         'url': 'https://s1.ticketm.net/dbimages/22674v.jpg',
#                                         'width': 205}],
#                             'locale': 'en-us',
#                             'location': {'latitude': '33.825315',
#                                          'longitude': '-116.542747'},
#                             'markets': [{'id': '27', 'name': 'Los Angeles'}],
#                             'name': 'Acrisure Arena at Greater Palm Springs',
#                             'postalCode': '92211',
#                             'state': {'name': 'California', 'stateCode': 'CA'},
#                             'test': False,
#                             'timezone': 'America/Los_Angeles',
#                             'type': 'venue',
#                             'upcomingEvents': {'_filtered': 0,
#                                                '_total': 92,
#                                                'ticketmaster': 92},
#                             'url': 'https://www.ticketmaster.com/acrisure-arena-at-greater-palm-springs-tickets-palm-desert/venue/82821'}]},
#   '_links': {'attractions': [{'href': '/discovery/v2/attractions/K8vZ9171xeV?locale=en-us'}],
#              'self': {'href': '/discovery/v2/events/vvG1IZbFSkKfhJ?locale=en-us'},
#              'venues': [{'href': '/discovery/v2/venues/KovZ917A-Tn?locale=en-us'}]},
#   'accessibility': {'id': 'accessibility', 'ticketLimit': 4},
#   'ageRestrictions': {'id': 'ageRestrictions', 'legalAgeEnforced': False},
#   'classifications': [{'family': False,
#                        'genre': {'id': 'KnvZfZ7vAev', 'name': 'Pop'},
#                        'primary': True,
#                        'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#                        'subGenre': {'id': 'KZazBEonSMnZfZ7vk1t', 'name': 'Pop'},
#                        'subType': {'id': 'KZFzBErXgnZfZ7v7lJ',
#                                    'name': 'Undefined'},
#                        'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}}],
#   'dates': {'spanMultipleDays': False,
#             'start': {'dateTBA': False,
#                       'dateTBD': False,
#                       'dateTime': '2024-11-03T02:30:00Z',
#                       'localDate': '2024-11-02',
#                       'localTime': '19:30:00',
#                       'noSpecificTime': False,
#                       'timeTBA': False},
#             'status': {'code': 'cancelled'},
#             'timezone': 'America/Los_Angeles'},
#   'id': 'vvG1IZbFSkKfhJ',
#   'images': [{'fallback': False,
#               'height': 225,
#               'ratio': '4_3',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_CUSTOM.jpg',
#               'width': 305},
#              {'fallback': False,
#               'height': 115,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_EVENT_DETAIL_PAGE_16_9.jpg',
#               'width': 205},
#              {'fallback': False,
#               'height': 203,
#               'ratio': '3_2',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_ARTIST_PAGE_3_2.jpg',
#               'width': 305},
#              {'fallback': False,
#               'height': 56,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RECOMENDATION_16_9.jpg',
#               'width': 100},
#              {'fallback': False,
#               'height': 1152,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#               'width': 2048},
#              {'fallback': False,
#               'height': 360,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_16_9.jpg',
#               'width': 640},
#              {'fallback': False,
#               'height': 576,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_16_9.jpg',
#               'width': 1024},
#              {'fallback': False,
#               'height': 639,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_LANDSCAPE_16_9.jpg',
#               'width': 1136},
#              {'fallback': False,
#               'height': 683,
#               'ratio': '3_2',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_3_2.jpg',
#               'width': 1024},
#              {'fallback': False,
#               'height': 1365,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_SOURCE',
#               'width': 2426},
#              {'fallback': False,
#               'height': 427,
#               'ratio': '3_2',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_3_2.jpg',
#               'width': 640}],
#   'locale': 'en-us',
#   'name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'pleaseNote': 'Unfortunately, the Event Organizer has had to cancel your '
#                 "event. You don't need to do a thing. We'll issue a refund to "
#                 'the original method of payment used at time of purchase, as '
#                 'soon as funds are received from the Event Organizer. It '
#                 'should appear on your account within 14-21 days. Please Note: '
#                 'If the tickets were transferred to you, the refund will go to '
#                 'the fan who originally purchased the tickets from '
#                 'Ticketmaster. Please see our Purchase Policy for more '
#                 'information.',
#   'priceRanges': [{'currency': 'USD',
#                    'max': 564.75,
#                    'min': 201.5,
#                    'type': 'standard'}],
#   'products': [{'classifications': [{'family': False,
#                                      'genre': {'id': 'KnvZfZ7v7ll',
#                                                'name': 'Undefined'},
#                                      'primary': True,
#                                      'segment': {'id': 'KZFzniwnSyZfZ7v7n1',
#                                                  'name': 'Miscellaneous'},
#                                      'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1',
#                                                   'name': 'Undefined'},
#                                      'subType': {'id': 'KZFzBErXgnZfZ7vAFe',
#                                                  'name': 'Regular'},
#                                      'type': {'id': 'KZAyXgnZfZ7vAva',
#                                               'name': 'Parking'}}],
#                 'id': 'vvG1IZbFTqLN_D',
#                 'name': 'PARKWHIZ ACRISURE ARENA AT GREATER PALM SPRINGS',
#                 'type': 'Upsell',
#                 'url': 'https://www.ticketmaster.com/parkwhiz-acrisure-arena-at-greater-palm-palm-desert-california-11-02-2024/event/0A00608FDD7E367B'}],
#   'promoter': {'description': 'LIVE NATION MUSIC / NTL / USA',
#                'id': '653',
#                'name': 'LIVE NATION MUSIC'},
#   'promoters': [{'description': 'LIVE NATION MUSIC / NTL / USA',
#                  'id': '653',
#                  'name': 'LIVE NATION MUSIC'}],
#   'sales': {'public': {'endDateTime': '2024-11-03T02:30:00Z',
#                        'startDateTime': '2024-04-22T17:00:00Z',
#                        'startTBA': False,
#                        'startTBD': False}},
#   'seatmap': {'id': 'seatmap',
#               'staticUrl': 'https://mapsapi.tmol.io/maps/geometry/3/event/0A00608CC64D46E6/staticImage?type=png&systemId=HOST'},
#   'test': False,
#   'ticketLimit': {'id': 'ticketLimit',
#                   'info': 'There is an overall 6 ticket limit for this event.'},
#   'ticketing': {'allInclusivePricing': {'enabled': True},
#                 'id': 'ticketing',
#                 'safeTix': {'enabled': True, 'inAppOnlyEnabled': False}},
#   'type': 'event',
#   'url': 'https://www.ticketmaster.com/shakira-las-mujeres-ya-no-lloran-palm-desert-california-11-02-2024/event/0A00608CC64D46E6'},
#  {'_embedded': {'attractions': [{'_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9171xeV?locale=en-us'}},
#                                  'aliases': ['sakira',
#                                              'shakira',
#                                              'shakira concert',
#                                              'shakria',
#                                              'sharika',
#                                              'sharkira',
#                                              'shikira',
#                                              'skakira'],
#                                  'classifications': [{'family': False,
#                                                       'genre': {'id': 'KnvZfZ7vAev',
#                                                                 'name': 'Pop'},
#                                                       'primary': True,
#                                                       'segment': {'id': 'KZFzniwnSyZfZ7v7nJ',
#                                                                   'name': 'Music'},
#                                                       'subGenre': {'id': 'KZazBEonSMnZfZ7vk1t',
#                                                                    'name': 'Pop'},
#                                                       'subType': {'id': 'KZFzBErXgnZfZ7vAde',
#                                                                   'name': 'Singer/Vocalist'},
#                                                       'type': {'id': 'KZAyXgnZfZ7v7la',
#                                                                'name': 'Individual'}}],
#                                  'externalLinks': {'facebook': [{'url': 'https://www.facebook.com/shakira'}],
#                                                    'homepage': [{'url': 'http://www.shakira-online.de/'}],
#                                                    'instagram': [{'url': 'https://instagram.com/shakira'}],
#                                                    'itunes': [{'url': 'https://itunes.apple.com/artist/id889327'}],
#                                                    'lastfm': [{'url': 'https://www.last.fm/music/Shakira'}],
#                                                    'musicbrainz': [{'id': 'bf24ca37-25f4-4e34-9aec-460b94364cfc',
#                                                                     'url': 'https://musicbrainz.org/artist/bf24ca37-25f4-4e34-9aec-460b94364cfc'}],
#                                                    'spotify': [{'url': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'}],
#                                                    'twitter': [{'url': 'https://twitter.com/shakira'}],
#                                                    'youtube': [{'url': 'https://www.youtube.com/user/shakira'}]},
#                                  'id': 'K8vZ9171xeV',
#                                  'images': [{'fallback': False,
#                                              'height': 225,
#                                              'ratio': '4_3',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_CUSTOM.jpg',
#                                              'width': 305},
#                                             {'fallback': False,
#                                              'height': 115,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_EVENT_DETAIL_PAGE_16_9.jpg',
#                                              'width': 205},
#                                             {'fallback': False,
#                                              'height': 203,
#                                              'ratio': '3_2',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_ARTIST_PAGE_3_2.jpg',
#                                              'width': 305},
#                                             {'fallback': False,
#                                              'height': 56,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RECOMENDATION_16_9.jpg',
#                                              'width': 100},
#                                             {'fallback': False,
#                                              'height': 1152,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#                                              'width': 2048},
#                                             {'fallback': False,
#                                              'height': 360,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_16_9.jpg',
#                                              'width': 640},
#                                             {'fallback': False,
#                                              'height': 576,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_16_9.jpg',
#                                              'width': 1024},
#                                             {'fallback': False,
#                                              'height': 639,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_LANDSCAPE_16_9.jpg',
#                                              'width': 1136},
#                                             {'fallback': False,
#                                              'height': 683,
#                                              'ratio': '3_2',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_3_2.jpg',
#                                              'width': 1024},
#                                             {'fallback': False,
#                                              'height': 1365,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_SOURCE',
#                                              'width': 2426},
#                                             {'fallback': False,
#                                              'height': 427,
#                                              'ratio': '3_2',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_3_2.jpg',
#                                              'width': 640}],
#                                  'locale': 'en-us',
#                                  'name': 'Shakira',
#                                  'test': False,
#                                  'type': 'attraction',
#                                  'upcomingEvents': {'_filtered': 0,
#                                                     '_total': 27,
#                                                     'ticketmaster': 27},
#                                  'url': 'https://www.ticketmaster.com.au/shakira-tickets/artist/779049'}],
#                 'venues': [{'_links': {'self': {'href': '/discovery/v2/venues/KovZ917A-Tn?locale=en-us'}},
#                             'address': {'line1': '75702 Varner Rd.'},
#                             'boxOfficeInfo': {'phoneNumberDetail': '760 835 '
#                                                                    '5100'},
#                             'city': {'name': 'Palm Desert'},
#                             'country': {'countryCode': 'US',
#                                         'name': 'United States Of America'},
#                             'dmas': [{'id': 223},
#                                      {'id': 324},
#                                      {'id': 354},
#                                      {'id': 383}],
#                             'id': 'KovZ917A-Tn',
#                             'images': [{'fallback': False,
#                                         'height': 115,
#                                         'ratio': '16_9',
#                                         'url': 'https://s1.ticketm.net/dbimages/22674v.jpg',
#                                         'width': 205}],
#                             'locale': 'en-us',
#                             'location': {'latitude': '33.825315',
#                                          'longitude': '-116.542747'},
#                             'markets': [{'id': '27', 'name': 'Los Angeles'}],
#                             'name': 'Acrisure Arena at Greater Palm Springs',
#                             'postalCode': '92211',
#                             'state': {'name': 'California', 'stateCode': 'CA'},
#                             'test': False,
#                             'timezone': 'America/Los_Angeles',
#                             'type': 'venue',
#                             'upcomingEvents': {'_filtered': 0,
#                                                '_total': 92,
#                                                'ticketmaster': 92},
#                             'url': 'https://www.ticketmaster.com/acrisure-arena-at-greater-palm-springs-tickets-palm-desert/venue/82821'}]},
#   '_links': {'attractions': [{'href': '/discovery/v2/attractions/K8vZ9171xeV?locale=en-us'}],
#              'self': {'href': '/discovery/v2/events/vvG1IZbFTpcNCA?locale=en-us'},
#              'venues': [{'href': '/discovery/v2/venues/KovZ917A-Tn?locale=en-us'}]},
#   'accessibility': {'id': 'accessibility', 'ticketLimit': 4},
#   'ageRestrictions': {'id': 'ageRestrictions', 'legalAgeEnforced': False},
#   'classifications': [{'family': False,
#                        'genre': {'id': 'KnvZfZ7vAev', 'name': 'Pop'},
#                        'primary': True,
#                        'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#                        'subGenre': {'id': 'KZazBEonSMnZfZ7vk1t', 'name': 'Pop'},
#                        'subType': {'id': 'KZFzBErXgnZfZ7v7lJ',
#                                    'name': 'Undefined'},
#                        'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}}],
#   'dates': {'spanMultipleDays': False,
#             'start': {'dateTBA': False,
#                       'dateTBD': False,
#                       'dateTime': '2024-11-04T03:30:00Z',
#                       'localDate': '2024-11-03',
#                       'localTime': '19:30:00',
#                       'noSpecificTime': False,
#                       'timeTBA': False},
#             'status': {'code': 'cancelled'},
#             'timezone': 'America/Los_Angeles'},
#   'id': 'vvG1IZbFTpcNCA',
#   'images': [{'fallback': False,
#               'height': 225,
#               'ratio': '4_3',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_CUSTOM.jpg',
#               'width': 305},
#              {'fallback': False,
#               'height': 115,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_EVENT_DETAIL_PAGE_16_9.jpg',
#               'width': 205},
#              {'fallback': False,
#               'height': 203,
#               'ratio': '3_2',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_ARTIST_PAGE_3_2.jpg',
#               'width': 305},
#              {'fallback': False,
#               'height': 56,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RECOMENDATION_16_9.jpg',
#               'width': 100},
#              {'fallback': False,
#               'height': 1152,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#               'width': 2048},
#              {'fallback': False,
#               'height': 360,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_16_9.jpg',
#               'width': 640},
#              {'fallback': False,
#               'height': 576,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_16_9.jpg',
#               'width': 1024},
#              {'fallback': False,
#               'height': 639,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_LANDSCAPE_16_9.jpg',
#               'width': 1136},
#              {'fallback': False,
#               'height': 683,
#               'ratio': '3_2',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_3_2.jpg',
#               'width': 1024},
#              {'fallback': False,
#               'height': 1365,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_SOURCE',
#               'width': 2426},
#              {'fallback': False,
#               'height': 427,
#               'ratio': '3_2',
#               'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_3_2.jpg',
#               'width': 640}],
#   'locale': 'en-us',
#   'name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'pleaseNote': 'Unfortunately, the Event Organizer has had to cancel your '
#                 "event. You don't need to do a thing. We'll issue a refund to "
#                 'the original method of payment used at time of purchase, as '
#                 'soon as funds are received from the Event Organizer. It '
#                 'should appear on your account within 14-21 days. Please Note: '
#                 'If the tickets were transferred to you, the refund will go to '
#                 'the fan who originally purchased the tickets from '
#                 'Ticketmaster. Please see our Purchase Policy for more '
#                 'information.',
#   'priceRanges': [{'currency': 'USD',
#                    'max': 564.75,
#                    'min': 201.5,
#                    'type': 'standard'}],
#   'products': [{'classifications': [{'family': False,
#                                      'genre': {'id': 'KnvZfZ7v7ll',
#                                                'name': 'Undefined'},
#                                      'primary': True,
#                                      'segment': {'id': 'KZFzniwnSyZfZ7v7n1',
#                                                  'name': 'Miscellaneous'},
#                                      'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1',
#                                                   'name': 'Undefined'},
#                                      'subType': {'id': 'KZFzBErXgnZfZ7vAFe',
#                                                  'name': 'Regular'},
#                                      'type': {'id': 'KZAyXgnZfZ7vAva',
#                                               'name': 'Parking'}}],
#                 'id': 'vvG1IZbavUsZB2',
#                 'name': 'PARKWHIZ ACRISURE ARENA AT GREATER PALM SPRINGS',
#                 'type': 'Upsell',
#                 'url': 'https://www.ticketmaster.com/parkwhiz-acrisure-arena-at-greater-palm-palm-desert-california-11-03-2024/event/0A00609076C40E8F'}],
#   'promoter': {'description': 'LIVE NATION MUSIC / NTL / USA',
#                'id': '653',
#                'name': 'LIVE NATION MUSIC'},
#   'promoters': [{'description': 'LIVE NATION MUSIC / NTL / USA',
#                  'id': '653',
#                  'name': 'LIVE NATION MUSIC'}],
#   'sales': {'public': {'endDateTime': '2024-11-04T03:30:00Z',
#                        'startDateTime': '2024-04-22T17:00:00Z',
#                        'startTBA': False,
#                        'startTBD': False}},
#   'seatmap': {'id': 'seatmap',
#               'staticUrl': 'https://mapsapi.tmol.io/maps/geometry/3/event/0A00608FD6B63385/staticImage?type=png&systemId=HOST'},
#   'test': False,
#   'ticketLimit': {'id': 'ticketLimit',
#                   'info': 'There is an overall 6 ticket limit for this event.'},
#   'ticketing': {'allInclusivePricing': {'enabled': True},
#                 'id': 'ticketing',
#                 'safeTix': {'enabled': True, 'inAppOnlyEnabled': False}},
#   'type': 'event',
#   'url': 'https://www.ticketmaster.com/shakira-las-mujeres-ya-no-lloran-palm-desert-california-11-03-2024/event/0A00608FD6B63385'},
#  {'_embedded': {'attractions': [{'_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9171xeV?locale=en-us'}},
#                                  'aliases': ['sakira',
#                                              'shakira',
#                                              'shakira concert',
#                                              'shakria',
#                                              'sharika',
#                                              'sharkira',
#                                              'shikira',
#                                              'skakira'],
#                                  'classifications': [{'family': False,
#                                                       'genre': {'id': 'KnvZfZ7vAev',
#                                                                 'name': 'Pop'},
#                                                       'primary': True,
#                                                       'segment': {'id': 'KZFzniwnSyZfZ7v7nJ',
#                                                                   'name': 'Music'},
#                                                       'subGenre': {'id': 'KZazBEonSMnZfZ7vk1t',
#                                                                    'name': 'Pop'},
#                                                       'subType': {'id': 'KZFzBErXgnZfZ7vAde',
#                                                                   'name': 'Singer/Vocalist'},
#                                                       'type': {'id': 'KZAyXgnZfZ7v7la',
#                                                                'name': 'Individual'}}],
#                                  'externalLinks': {'facebook': [{'url': 'https://www.facebook.com/shakira'}],
#                                                    'homepage': [{'url': 'http://www.shakira-online.de/'}],
#                                                    'instagram': [{'url': 'https://instagram.com/shakira'}],
#                                                    'itunes': [{'url': 'https://itunes.apple.com/artist/id889327'}],
#                                                    'lastfm': [{'url': 'https://www.last.fm/music/Shakira'}],
#                                                    'musicbrainz': [{'id': 'bf24ca37-25f4-4e34-9aec-460b94364cfc',
#                                                                     'url': 'https://musicbrainz.org/artist/bf24ca37-25f4-4e34-9aec-460b94364cfc'}],
#                                                    'spotify': [{'url': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'}],
#                                                    'twitter': [{'url': 'https://twitter.com/shakira'}],
#                                                    'youtube': [{'url': 'https://www.youtube.com/user/shakira'}]},
#                                  'id': 'K8vZ9171xeV',
#                                  'images': [{'fallback': False,
#                                              'height': 225,
#                                              'ratio': '4_3',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_CUSTOM.jpg',
#                                              'width': 305},
#                                             {'fallback': False,
#                                              'height': 115,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_EVENT_DETAIL_PAGE_16_9.jpg',
#                                              'width': 205},
#                                             {'fallback': False,
#                                              'height': 203,
#                                              'ratio': '3_2',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_ARTIST_PAGE_3_2.jpg',
#                                              'width': 305},
#                                             {'fallback': False,
#                                              'height': 56,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RECOMENDATION_16_9.jpg',
#                                              'width': 100},
#                                             {'fallback': False,
#                                              'height': 1152,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#                                              'width': 2048},
#                                             {'fallback': False,
#                                              'height': 360,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_16_9.jpg',
#                                              'width': 640},
#                                             {'fallback': False,
#                                              'height': 576,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_16_9.jpg',
#                                              'width': 1024},
#                                             {'fallback': False,
#                                              'height': 639,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_LANDSCAPE_16_9.jpg',
#                                              'width': 1136},
#                                             {'fallback': False,
#                                              'height': 683,
#                                              'ratio': '3_2',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_3_2.jpg',
#                                              'width': 1024},
#                                             {'fallback': False,
#                                              'height': 1365,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_SOURCE',
#                                              'width': 2426},
#                                             {'fallback': False,
#                                              'height': 427,
#                                              'ratio': '3_2',
#                                              'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_3_2.jpg',
#                                              'width': 640}],
#                                  'locale': 'en-us',
#                                  'name': 'Shakira',
#                                  'test': False,
#                                  'type': 'attraction',
#                                  'upcomingEvents': {'_filtered': 0,
#                                                     '_total': 27,
#                                                     'ticketmaster': 27},
#                                  'url': 'https://www.ticketmaster.com.au/shakira-tickets/artist/779049'}],
#                 'venues': [{'_links': {'self': {'href': '/discovery/v2/venues/KovZpZAEkn6A?locale=en-us'}},
#                             'accessibleSeatingDetail': 'Wheelchair and '
#                                                        'Disabled Seating '
#                                                        'Policy: Wheelchair and '
#                                                        'Transfer seating is '
#                                                        'reserved exclusively '
#                                                        'for patrons with '
#                                                        'accessible needs and '
#                                                        'their companions. '
#                                                        'Accessible seating is '
#                                                        'intended for use by an '
#                                                        'individual with a '
#                                                        'mobility disability or '
#                                                        'other disability who '
#                                                        'requires the '
#                                                        'accessible features of '
#                                                        'accessible seating due '
#                                                        'to a disability, and '
#                                                        "that individual's "
#                                                        'companions. Kia Forum '
#                                                        'reserves the right to '
#                                                        'investigate potential '
#                                                        'misuse of accessible '
#                                                        'seating and to take '
#                                                        'all appropriate action '
#                                                        'against individuals '
#                                                        'who fraudulently '
#                                                        'obtain tickets for '
#                                                        'accessible seating. In '
#                                                        'the event such ticket '
#                                                        'is transferred to a '
#                                                        'non-disabled '
#                                                        'individual, Kia Forum '
#                                                        'reserves the right to '
#                                                        'deny entry to the '
#                                                        'wheelchair seating '
#                                                        'area or transfer that '
#                                                        'individual to other '
#                                                        'available seating. '
#                                                        'Wheelchair and '
#                                                        'Disabled Seating '
#                                                        'Tickets for people '
#                                                        'with accessible needs, '
#                                                        'subject to '
#                                                        'availability, may be '
#                                                        'purchased in several '
#                                                        'ways: 1) Order Online '
#                                                        'with Ticketmaster 2) '
#                                                        'Call Kia Forum Guest '
#                                                        'Relations at '
#                                                        '310-862-6200. For '
#                                                        'additional information '
#                                                        'regarding '
#                                                        'accessibility at Kia '
#                                                        'Forum or to request an '
#                                                        'interpreted '
#                                                        'performance or any '
#                                                        'other accommodations, '
#                                                        'please call Kia Forum '
#                                                        'Guest Relations '
#                                                        'Department Monday to '
#                                                        'Friday, 11am to 7pm. '
#                                                        'Accessible Restrooms, '
#                                                        'Disabled and family '
#                                                        'restrooms are located '
#                                                        'on the concourse '
#                                                        'across from sections '
#                                                        '209-210 and 227-228. '
#                                                        'On the floor, disabled '
#                                                        'restrooms are located '
#                                                        'in the hallways '
#                                                        'adjacent to the North '
#                                                        'Hospitality. While '
#                                                        'disabled guests are '
#                                                        'provided preference at '
#                                                        'disabled restrooms, '
#                                                        'any guest may use '
#                                                        'these restrooms if '
#                                                        'they require that type '
#                                                        'of accommodation. Kia '
#                                                        'Forum can provide '
#                                                        'wheelchair escorts for '
#                                                        'individuals who have '
#                                                        'limited mobility to '
# ...
#                                              'width': 205},
#                                             {'fallback': False,
#                                              'height': 1152,
#                                              'ratio': '16_9',
#                                              'url': 'https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#                                              'width': 2048},
#                                             {'fallback': False,
#                                              'height': 225,
#                                              'ratio': '4_3',
#                                              'url': 'https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_CUSTOM.jpg',
#                                              'width': 305}],
#                                  'locale': 'en-us',
#                                  'name': 'Shakira',
#                                  'test': False,
#                                  'type': 'attraction',
#                                  'upcomingEvents': {'_filtered': 0,
#                                                     '_total': 27,
#                                                     'ticketmaster': 27},
#                                  'url': 'https://www.ticketmaster.com.au/shakira-tickets/artist/779049'}],
#                 'venues': [{'_links': {'self': {'href': '/discovery/v2/venues/KovZpZAd1IaA?locale=en-us'}},
#                             'accessibleSeatingDetail': 'Los boletos se pueden '
#                                                        'adquirir tanto en el '
#                                                        '53259000 como en '
#                                                        'taquillas Conciertos: '
#                                                        'Se tiene un area '
#                                                        'asignada especial a '
#                                                        'nivel pista para dar '
#                                                        'el servicio.',
#                             'ada': {'adaCustomCopy': 'INFORMATION',
#                                     'adaHours': 'Monday to Friday 8am-10pm, '
#                                                 'Saturday 9am-9pm, Sunday and '
#                                                 'Holidays 10am-7pm',
#                                     'adaPhones': 'Questions or comments '
#                                                  'contactanos@ticketmaster.com.mx'},
#                             'address': {'line1': 'Viaducto Piedad y Río '
#                                                  'Churubusco s/n Cd. '
#                                                  'Deportiva'},
#                             'boxOfficeInfo': {'acceptedPaymentDetail': 'Efectivo,Tarjeta '
#                                                                        'de '
#                                                                        'Credito '
#                                                                        'y '
#                                                                        'Debito',
#                                               'openHoursDetail': 'Solo dia del '
#                                                                  'evento',
#                                               'phoneNumberDetail': '(55) '
#                                                                    '52379999 '
#                                                                    'ext. 71008',
#                                               'willCallDetail': 'CONCIERTOS : '
#                                                                 'El dia del '
#                                                                 'evento en la '
#                                                                 'taquilla de '
#                                                                 'Puerta 5 de '
#                                                                 'Ciudad '
#                                                                 'Deportiva en '
#                                                                 'Horario de '
#                                                                 '10:00 hasta '
#                                                                 '45 minutos '
#                                                                 'despues de '
#                                                                 'iniciado el '
#                                                                 'evento.'},
#                             'city': {'name': 'Cdmx'},
#                             'country': {'countryCode': 'MX', 'name': 'Mexico'},
#                             'dmas': [{'id': 801}, {'id': 802}],
#                             'generalInfo': {'childRule': 'Dependiendo del '
#                                                          'evento ni�os pagan a '
#                                                          'partir de 3 a�os.',
#                                             'generalRule': 'No se permite el '
#                                                            'acceso con camaras '
#                                                            'de video, camaras '
#                                                            'fotograficas '
#                                                            'profesionales, '
#                                                            'alimentos y '
#                                                            'bebidas, mascotas, '
#                                                            'armas, paraguas, '
#                                                            'mochilas.'},
#                             'id': 'KovZpZAd1IaA',
#                             'locale': 'en-us',
#                             'location': {'latitude': '19.405199',
#                                          'longitude': '-99.095618'},
#                             'markets': [{'id': '401', 'name': 'All of Mexico'},
#                                         {'id': '402',
#                                          'name': 'Mexico City and Metropolitan '
#                                                  'Area'}],
#                             'name': 'Estadio GNP Seguros',
#                             'parkingDetail': 'Dentro de la Cd. Deportiva Esta '
#                                              'a la venta Unicamente por '
#                                              'Centros Ticketmaster y Taquilla '
#                                              'Para conciertos acceso por '
#                                              'puerta 7, 8 y 9 de Ciudad '
#                                              'Deportiva.',
#                             'postalCode': '08400',
#                             'state': {'name': 'Ciudad de México',
#                                       'stateCode': 'DF'},
#                             'test': False,
#                             'timezone': 'America/Mexico_City',
#                             'type': 'venue',
#                             'upcomingEvents': {'_filtered': 0,
#                                                '_total': 66,
#                                                'archtics': 12,
#                                                'ticketmaster': 54},
#                             'url': 'https://www.ticketmaster.com.mx/estadio-gnp-seguros-tickets-cdmx/venue/163903'}]},
#   '_links': {'attractions': [{'href': '/discovery/v2/attractions/K8vZ9171xeV?locale=en-us'}],
#              'self': {'href': '/discovery/v2/events/1kAZv-AIGA5q8JQ?locale=en-us'},
#              'venues': [{'href': '/discovery/v2/venues/KovZpZAd1IaA?locale=en-us'}]},
#   'accessibility': {'id': 'accessibility', 'ticketLimit': 2},
#   'ageRestrictions': {'id': 'ageRestrictions', 'legalAgeEnforced': False},
#   'classifications': [{'family': False,
#                        'genre': {'id': 'KnvZfZ7vAev', 'name': 'Pop'},
#                        'primary': True,
#                        'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#                        'subGenre': {'id': 'KZazBEonSMnZfZ7vk1t', 'name': 'Pop'},
#                        'subType': {'id': 'KZFzBErXgnZfZ7v7lJ',
#                                    'name': 'Undefined'},
#                        'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}}],
#   'dates': {'spanMultipleDays': False,
#             'start': {'dateTBA': False,
#                       'dateTBD': False,
#                       'dateTime': '2025-03-24T01:00:00Z',
#                       'localDate': '2025-03-23',
#                       'localTime': '19:00:00',
#                       'noSpecificTime': False,
#                       'timeTBA': False},
#             'status': {'code': 'onsale'},
#             'timezone': 'America/Mexico_City'},
#   'id': '1kAZv-AIGA5q8JQ',
#   'images': [{'fallback': False,
#               'height': 683,
#               'ratio': '3_2',
#               'url': 'https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_TABLET_LANDSCAPE_3_2.jpg',
#               'width': 1024},
#              {'fallback': False,
#               'height': 639,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_RETINA_LANDSCAPE_16_9.jpg',
#               'width': 1136},
#              {'fallback': False,
#               'height': 576,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_TABLET_LANDSCAPE_16_9.jpg',
#               'width': 1024},
#              {'fallback': False,
#               'height': 1365,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_SOURCE',
#               'width': 2426},
#              {'fallback': False,
#               'height': 427,
#               'ratio': '3_2',
#               'url': 'https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_RETINA_PORTRAIT_3_2.jpg',
#               'width': 640},
#              {'fallback': False,
#               'height': 203,
#               'ratio': '3_2',
#               'url': 'https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_ARTIST_PAGE_3_2.jpg',
#               'width': 305},
#              {'fallback': False,
#               'height': 360,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_RETINA_PORTRAIT_16_9.jpg',
#               'width': 640},
#              {'fallback': False,
#               'height': 56,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_RECOMENDATION_16_9.jpg',
#               'width': 100},
#              {'fallback': False,
#               'height': 115,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_EVENT_DETAIL_PAGE_16_9.jpg',
#               'width': 205},
#              {'fallback': False,
#               'height': 1152,
#               'ratio': '16_9',
#               'url': 'https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#               'width': 2048},
#              {'fallback': False,
#               'height': 225,
#               'ratio': '4_3',
#               'url': 'https://s1.ticketm.net/dam/a/451/8eba6836-0ae5-42e6-96ac-f1bc310e8451_CUSTOM.jpg',
#               'width': 305}],
#   'info': 'Las Mujeres Ya No Lloran World Tour es un homenaje a la popular '
#           'música de Shakira, con una mirada hacia el futuro. Inspirada en su '
#           'álbum Las Mujeres Ya No Lloran, esta gira promueve un mensaje de '
#           'empoderamiento y fortaleza, que Shakira busca transmitir a varias '
#           'generaciones de fans, quienes nunca la han visto en vivo o a los '
#           'que llevan varios años esperando su regreso. Con una nueva '
#           'producción diseñada con la más alta tecnología, sus mayores éxitos, '
#           'canciones nuevas y varias sorpresas, la gira aspira a ser una '
#           'experiencia inolvidable, tanto visual como musicalmente. En este '
#           'regreso a los escenarios de Latinoamérica, Shakira busca crear un '
#           'espacio donde sus fans podrán compartir y celebrar con ella el '
#           'poder del renacimiento personal tal como un diamante, que se forma '
#           'bajo presión y emerge más fuerte y brillante tras las adversidades.',
#   'locale': 'en-us',
#   'name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'pleaseNote': 'Límite de edad: No hay Pagan boleto a partir de: 3 años '
#                 'Restricciones: No pueden ingresar al evento con: Objetos '
#                 'punzocortantes, mascotas, lasers, comida, bebida, sombrillas, '
#                 'aerosoles, bolsas que superen los 30x30cm, botellas de '
#                 'cualquier tipo, latas, sillas, cobijas, anforitas, navajas, '
#                 'pirotecnia, spray pimienta, drogas, sustancias ilícitas, '
#                 'cámaras de foto profesionales, cámaras de video o equipo de '
#                 'grabación de audio',
#   'priceRanges': [{'currency': 'MXN',
#                    'max': 8899.0,
#                    'min': 998.0,
#                    'type': 'standard'}],
#   'products': [{'classifications': [{'family': False,
#                                      'genre': {'id': 'KnvZfZ7v7ll',
#                                                'name': 'Undefined'},
#                                      'primary': True,
#                                      'segment': {'id': 'KZFzniwnSyZfZ7v7n1',
#                                                  'name': 'Miscellaneous'},
#                                      'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1',
#                                                   'name': 'Undefined'},
#                                      'subType': {'id': 'KZFzBErXgnZfZ7vAFe',
#                                                  'name': 'Regular'},
#                                      'type': {'id': 'KZAyXgnZfZ7vAva',
#                                               'name': 'Parking'}}],
#                 'id': '1Av8ZbfGkHF8N71',
#                 'name': 'Ticket2ride Shakira',
#                 'type': 'Upsell',
#                 'url': 'http://www.ticketmaster.com.mx/ticket2ride-shakira-cdmx-ciudad-de-mexico-03-23-2025/event/1400614F0842310A'}],
#   'promoter': {'description': 'OCESA / NTL / MXC',
#                'id': '304',
#                'name': 'OCESA'},
#   'promoters': [{'description': 'OCESA / NTL / MXC',
#                  'id': '304',
#                  'name': 'OCESA'},
#                 {'description': 'MONDIAL PRICE 1 / NTL / MXC',
#                  'id': '3323',
#                  'name': 'MONDIAL PRICE 1'}],
#   'sales': {'presales': [{'endDateTime': '2024-10-15T05:59:00Z',
#                           'name': 'Preventa Citibanamex',
#                           'startDateTime': '2024-10-14T20:00:00Z'}],
#             'public': {'endDateTime': '2025-03-24T01:00:00Z',
#                        'startDateTime': '2024-10-15T20:00:00Z',
#                        'startTBA': False,
#                        'startTBD': False}},
#   'seatmap': {'id': 'seatmap',
#               'staticUrl': 'https://s1.ticketm.net/tmimages/venue/maps/mxc/104759s.gif'},
#   'test': False,
#   'ticketLimit': {'id': 'ticketLimit',
#                   'info': 'Limitado a 8 boletos por comprador. Por favor '
#                           'revisa los detalles de cada tipo de boleto, ya que '
#                           'en ocasiones éstos pueden contar con un límite '
#                           'distinto.'},
#   'ticketing': {'allInclusivePricing': {'enabled': False},
#                 'id': 'ticketing',
#                 'safeTix': {'enabled': True, 'inAppOnlyEnabled': False}},
#   'type': 'event',
#   'url': 'https://www.ticketmaster.com.mx/shakira-las-mujeres-ya-no-lloran-cdmx-23-03-2025/event/140061168B75099A'}]

# %%
# Print first concert
concerts[0]
# Out:
# {'name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#  'type': 'event',
#  'id': 'vvG1IZbFSkKfhJ',
#  'test': False,
#  'url': 'https://www.ticketmaster.com/shakira-las-mujeres-ya-no-lloran-palm-desert-california-11-02-2024/event/0A00608CC64D46E6',
#  'locale': 'en-us',
#  'images': [{'ratio': '4_3',
#    'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_CUSTOM.jpg',
#    'width': 305,
#    'height': 225,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_EVENT_DETAIL_PAGE_16_9.jpg',
#    'width': 205,
#    'height': 115,
#    'fallback': False},
#   {'ratio': '3_2',
#    'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_ARTIST_PAGE_3_2.jpg',
#    'width': 305,
#    'height': 203,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RECOMENDATION_16_9.jpg',
#    'width': 100,
#    'height': 56,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#    'width': 2048,
#    'height': 1152,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_16_9.jpg',
#    'width': 640,
#    'height': 360,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_16_9.jpg',
#    'width': 1024,
#    'height': 576,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_LANDSCAPE_16_9.jpg',
#    'width': 1136,
#    'height': 639,
#    'fallback': False},
#   {'ratio': '3_2',
#    'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_3_2.jpg',
#    'width': 1024,
#    'height': 683,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_SOURCE',
#    'width': 2426,
#    'height': 1365,
#    'fallback': False},
#   {'ratio': '3_2',
#    'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_3_2.jpg',
#    'width': 640,
#    'height': 427,
#    'fallback': False}],
#  'sales': {'public': {'startDateTime': '2024-04-22T17:00:00Z',
#    'startTBD': False,
#    'startTBA': False,
#    'endDateTime': '2024-11-03T02:30:00Z'}},
#  'dates': {'start': {'localDate': '2024-11-02',
#    'localTime': '19:30:00',
#    'dateTime': '2024-11-03T02:30:00Z',
#    'dateTBD': False,
#    'dateTBA': False,
#    'timeTBA': False,
#    'noSpecificTime': False},
#   'timezone': 'America/Los_Angeles',
#   'status': {'code': 'cancelled'},
#   'spanMultipleDays': False},
#  'classifications': [{'primary': True,
#    'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#    'genre': {'id': 'KnvZfZ7vAev', 'name': 'Pop'},
#    'subGenre': {'id': 'KZazBEonSMnZfZ7vk1t', 'name': 'Pop'},
#    'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#    'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#    'family': False}],
#  'promoter': {'id': '653',
#   'name': 'LIVE NATION MUSIC',
#   'description': 'LIVE NATION MUSIC / NTL / USA'},
#  'promoters': [{'id': '653',
#    'name': 'LIVE NATION MUSIC',
#    'description': 'LIVE NATION MUSIC / NTL / USA'}],
#  'pleaseNote': "Unfortunately, the Event Organizer has had to cancel your event. You don't need to do a thing. We'll issue a refund to the original method of payment used at time of purchase, as soon as funds are received from the Event Organizer. It should appear on your account within 14-21 days. Please Note: If the tickets were transferred to you, the refund will go to the fan who originally purchased the tickets from Ticketmaster. Please see our Purchase Policy for more information.",
#  'priceRanges': [{'type': 'standard',
#    'currency': 'USD',
#    'min': 201.5,
#    'max': 564.75}],
#  'products': [{'name': 'PARKWHIZ ACRISURE ARENA AT GREATER PALM SPRINGS',
#    'id': 'vvG1IZbFTqLN_D',
#    'url': 'https://www.ticketmaster.com/parkwhiz-acrisure-arena-at-greater-palm-palm-desert-california-11-02-2024/event/0A00608FDD7E367B',
#    'type': 'Upsell',
#    'classifications': [{'primary': True,
#      'segment': {'id': 'KZFzniwnSyZfZ7v7n1', 'name': 'Miscellaneous'},
#      'genre': {'id': 'KnvZfZ7v7ll', 'name': 'Undefined'},
#      'subGenre': {'id': 'KZazBEonSMnZfZ7vAv1', 'name': 'Undefined'},
#      'type': {'id': 'KZAyXgnZfZ7vAva', 'name': 'Parking'},
#      'subType': {'id': 'KZFzBErXgnZfZ7vAFe', 'name': 'Regular'},
#      'family': False}]}],
#  'seatmap': {'staticUrl': 'https://mapsapi.tmol.io/maps/geometry/3/event/0A00608CC64D46E6/staticImage?type=png&systemId=HOST',
#   'id': 'seatmap'},
#  'accessibility': {'ticketLimit': 4, 'id': 'accessibility'},
#  'ticketLimit': {'info': 'There is an overall 6 ticket limit for this event.',
#   'id': 'ticketLimit'},
#  'ageRestrictions': {'legalAgeEnforced': False, 'id': 'ageRestrictions'},
#  'ticketing': {'safeTix': {'enabled': True, 'inAppOnlyEnabled': False},
#   'allInclusivePricing': {'enabled': True},
#   'id': 'ticketing'},
#  '_links': {'self': {'href': '/discovery/v2/events/vvG1IZbFSkKfhJ?locale=en-us'},
#   'attractions': [{'href': '/discovery/v2/attractions/K8vZ9171xeV?locale=en-us'}],
#   'venues': [{'href': '/discovery/v2/venues/KovZ917A-Tn?locale=en-us'}]},
#  '_embedded': {'venues': [{'name': 'Acrisure Arena at Greater Palm Springs',
#     'type': 'venue',
#     'id': 'KovZ917A-Tn',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/acrisure-arena-at-greater-palm-springs-tickets-palm-desert/venue/82821',
#     'locale': 'en-us',
#     'images': [{'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dbimages/22674v.jpg',
#       'width': 205,
#       'height': 115,
#       'fallback': False}],
#     'postalCode': '92211',
#     'timezone': 'America/Los_Angeles',
#     'city': {'name': 'Palm Desert'},
#     'state': {'name': 'California', 'stateCode': 'CA'},
#     'country': {'name': 'United States Of America', 'countryCode': 'US'},
#     'address': {'line1': '75702 Varner Rd.'},
#     'location': {'longitude': '-116.542747', 'latitude': '33.825315'},
#     'markets': [{'name': 'Los Angeles', 'id': '27'}],
#     'dmas': [{'id': 223}, {'id': 324}, {'id': 354}, {'id': 383}],
#     'boxOfficeInfo': {'phoneNumberDetail': '760 835 5100'},
#     'upcomingEvents': {'ticketmaster': 92, '_total': 92, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/KovZ917A-Tn?locale=en-us'}}}],
#   'attractions': [{'name': 'Shakira',
#     'type': 'attraction',
#     'id': 'K8vZ9171xeV',
#     'test': False,
#     'url': 'https://www.ticketmaster.com.au/shakira-tickets/artist/779049',
#     'locale': 'en-us',
#     'externalLinks': {'youtube': [{'url': 'https://www.youtube.com/user/shakira'}],
#      'twitter': [{'url': 'https://twitter.com/shakira'}],
#      'itunes': [{'url': 'https://itunes.apple.com/artist/id889327'}],
#      'lastfm': [{'url': 'https://www.last.fm/music/Shakira'}],
#      'spotify': [{'url': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'}],
#      'facebook': [{'url': 'https://www.facebook.com/shakira'}],
#      'musicbrainz': [{'id': 'bf24ca37-25f4-4e34-9aec-460b94364cfc',
#        'url': 'https://musicbrainz.org/artist/bf24ca37-25f4-4e34-9aec-460b94364cfc'}],
#      'instagram': [{'url': 'https://instagram.com/shakira'}],
#      'homepage': [{'url': 'http://www.shakira-online.de/'}]},
#     'aliases': ['sakira',
#      'shakira',
#      'shakira concert',
#      'shakria',
#      'sharika',
#      'sharkira',
#      'shikira',
#      'skakira'],
#     'images': [{'ratio': '4_3',
#       'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_CUSTOM.jpg',
#       'width': 305,
#       'height': 225,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_EVENT_DETAIL_PAGE_16_9.jpg',
#       'width': 205,
#       'height': 115,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_ARTIST_PAGE_3_2.jpg',
#       'width': 305,
#       'height': 203,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RECOMENDATION_16_9.jpg',
#       'width': 100,
#       'height': 56,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#       'width': 2048,
#       'height': 1152,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_16_9.jpg',
#       'width': 640,
#       'height': 360,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_16_9.jpg',
#       'width': 1024,
#       'height': 576,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_LANDSCAPE_16_9.jpg',
#       'width': 1136,
#       'height': 639,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_TABLET_LANDSCAPE_3_2.jpg',
#       'width': 1024,
#       'height': 683,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_SOURCE',
#       'width': 2426,
#       'height': 1365,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/948/b2af9578-af9a-4d19-ba25-a8d2ef7f7948_RETINA_PORTRAIT_3_2.jpg',
#       'width': 640,
#       'height': 427,
#       'fallback': False}],
#     'classifications': [{'primary': True,
#       'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#       'genre': {'id': 'KnvZfZ7vAev', 'name': 'Pop'},
#       'subGenre': {'id': 'KZazBEonSMnZfZ7vk1t', 'name': 'Pop'},
#       'type': {'id': 'KZAyXgnZfZ7v7la', 'name': 'Individual'},
#       'subType': {'id': 'KZFzBErXgnZfZ7vAde', 'name': 'Singer/Vocalist'},
#       'family': False}],
#     'upcomingEvents': {'ticketmaster': 27, '_total': 27, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ9171xeV?locale=en-us'}}}]}}

# %%
# Create a list of dictionaries to store the key information about the concert and tickets price
dict_of_concerts = {}

# Loop throug all the concerts and extract relevant information
for concert in concerts:
    concert_dict = {}

    if (concert['dates']['status']['code'] != 'offsale'):
        # Use the concert ID as the index to add the concert_dict to the dict_of_concerts
        concert_id = concert['id']

        concert_name = concert['name']
        concert_dict['Concert_Name'] = concert_name
        concert_date = concert['dates']['start']['localDate']
        concert_dict['Concert_Date'] = concert_date
        ticket_sale_status = concert['dates']['status']['code']
        concert_dict['Ticket_Sale_Status'] = ticket_sale_status

        # Use a try-except statement for varables that aren't necessarily common to all the concerts
        try:
            ticket_min_price = concert['priceRanges'][0]['min']
            concert_dict['Ticket_Min_Price'] = ticket_min_price
            ticket_max_price = concert['priceRanges'][0]['max']
            concert_dict['Ticket_Max_Price'] = ticket_max_price
        except (KeyError):
            concert_dict['Ticket_Min_Price'] = 'Concert is in presale. General pricing is not available'
            concert_dict['Ticket_Max_Price'] = 'Concert is in presale. General pricing is not available'

        try:
            ticket_limit = concert['ticketLimit']['info']
            concert_dict['Ticket_Limitation'] = ticket_limit
        except (KeyError):
            concert_dict['Ticket_Limitation'] = 'No Limit'

        venue_id = concert['_embedded']['venues'][0]['id']
        concert_dict['Venue_ID'] = venue_id

        # Add the concert_dict to the dict_of_concerts
        dict_of_concerts[concert_id] = concert_dict

dict_of_concerts
# Out:
# {'vvG1IZbFSkKfhJ': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2024-11-02',
#   'Ticket_Sale_Status': 'cancelled',
#   'Ticket_Min_Price': 201.5,
#   'Ticket_Max_Price': 564.75,
#   'Ticket_Limitation': 'There is an overall 6 ticket limit for this event.',
#   'Venue_ID': 'KovZ917A-Tn'},
#  'vvG1IZbFTpcNCA': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2024-11-03',
#   'Ticket_Sale_Status': 'cancelled',
#   'Ticket_Min_Price': 201.5,
#   'Ticket_Max_Price': 564.75,
#   'Ticket_Limitation': 'There is an overall 6 ticket limit for this event.',
#   'Venue_ID': 'KovZ917A-Tn'},
#  'vv170ZbFGkMDd4OB': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2024-11-09',
#   'Ticket_Sale_Status': 'cancelled',
#   'Ticket_Min_Price': 249.5,
#   'Ticket_Max_Price': 589.5,
#   'Ticket_Limitation': 'There is an overall 6 ticket limit for this event.',
#   'Venue_ID': 'KovZpZAEkn6A'},
#  'G5dIZbFwIrgO8': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2024-11-16',
#   'Ticket_Sale_Status': 'cancelled',
#   'Ticket_Min_Price': 189.5,
#   'Ticket_Max_Price': 499.5,
#   'Ticket_Limitation': 'There is an overall 6 ticket limit for this event.',
#   'Venue_ID': 'KovZpZAJJEdA'},
#  'vvG1YZbFSrWgPY': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2024-11-17',
#   'Ticket_Sale_Status': 'cancelled',
#   'Ticket_Min_Price': 149.5,
#   'Ticket_Max_Price': 491.5,
#   'Ticket_Limitation': 'There is an overall 6 ticket limit for this event.',
#   'Venue_ID': 'KovZpZAJ67eA'},
#  'vvG1VZbFU3Rv5A': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2024-11-20',
#   'Ticket_Sale_Status': 'cancelled',
#   'Ticket_Min_Price': 145.5,
#   'Ticket_Max_Price': 485.5,
#   'Ticket_Limitation': 'There is a six (6) ticket limit for this event.',
#   'Venue_ID': 'KovZpZAJtFaA'},
#  'vvG1VZbFX9ZdVo': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2024-11-21',
#   'Ticket_Sale_Status': 'cancelled',
#   'Ticket_Min_Price': 145.5,
#   'Ticket_Max_Price': 485.5,
#   'Ticket_Limitation': 'There is a six (6) ticket limit for this event.',
#   'Venue_ID': 'KovZpZAJtFaA'},
#  'G5eVZbFMbObre': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2024-11-23',
#   'Ticket_Sale_Status': 'cancelled',
#   'Ticket_Min_Price': 129.5,
#   'Ticket_Max_Price': 429.5,
#   'Ticket_Limitation': 'No Limit',
#   'Venue_ID': 'KovZpZA6AEIA'},
#  '1AvfZbFGkRnDJIs': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2024-11-25',
#   'Ticket_Sale_Status': 'cancelled',
#   'Ticket_Min_Price': 129.5,
#   'Ticket_Max_Price': 429.5,
#   'Ticket_Limitation': 'There is an overall 6 ticket limit for this event.',
#   'Venue_ID': 'KovZpaKuJe'},
#  '1AdZZbFGkww3sSf': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2024-12-05',
#   'Ticket_Sale_Status': 'cancelled',
#   'Ticket_Min_Price': 149.5,
#   'Ticket_Max_Price': 489.5,
#   'Ticket_Limitation': 'There is a 6 ticket limit on this event',
#   'Venue_ID': 'KovZ917AtP3'},
#  '1AYZke8GkdyGvh8': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2024-12-06',
#   'Ticket_Sale_Status': 'cancelled',
#   'Ticket_Min_Price': 149.5,
#   'Ticket_Max_Price': 489.5,
#   'Ticket_Limitation': 'There is a 6 ticket limit on this event',
#   'Venue_ID': 'KovZ917AtP3'},
#  'vv177ZbFGkwEuVoY': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2024-12-08',
#   'Ticket_Sale_Status': 'cancelled',
#   'Ticket_Min_Price': 119.5,
#   'Ticket_Max_Price': 399.5,
#   'Ticket_Limitation': 'There is an overall 6 ticket limit for this event.',
#   'Venue_ID': 'KovZpa2gne'},
#  'vv178ZbFGkR05dgA': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2024-12-14',
#   'Ticket_Sale_Status': 'cancelled',
#   'Ticket_Min_Price': 144.5,
#   'Ticket_Max_Price': 485.0,
#   'Ticket_Limitation': 'There is an overall 6 ticket limit for this event.',
#   'Venue_ID': 'KovZpa2M7e'},
#  'G5dVZbor9h-KC': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2025-03-12',
#   'Ticket_Sale_Status': 'onsale',
#   'Ticket_Min_Price': 599.0,
#   'Ticket_Max_Price': 6599.0,
#   'Ticket_Limitation': 'Limitado a 8 boletos por comprador. Por favor revisa los detalles de cada tipo de boleto, ya que en ocasiones éstos pueden contar con un límite distinto.',
#   'Venue_ID': 'KovZpZAEeI7A'},
#  'G5dVZboLnUfWx': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2025-03-13',
#   'Ticket_Sale_Status': 'onsale',
#   'Ticket_Min_Price': 599.0,
#   'Ticket_Max_Price': 6599.0,
#   'Ticket_Limitation': 'Limitado a 8 boletos por comprador. Por favor revisa los detalles de cada tipo de boleto, ya que en ocasiones éstos pueden contar con un límite distinto.',
#   'Venue_ID': 'KovZpZAEeI7A'},
#  'G5dVZbonKI-2s': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2025-03-16',
#   'Ticket_Sale_Status': 'onsale',
#   'Ticket_Min_Price': 998.0,
#   'Ticket_Max_Price': 6599.0,
#   'Ticket_Limitation': 'Limitado a 8 boletos por comprador. Por favor revisa los detalles de cada tipo de boleto, ya que en ocasiones éstos pueden contar con un límite distinto.',
#   'Venue_ID': 'KovZpZA6IlFA'},
#  'G5dVZbonEToPC': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2025-03-17',
#   'Ticket_Sale_Status': 'onsale',
#   'Ticket_Min_Price': 998.0,
#   'Ticket_Max_Price': 6599.0,
#   'Ticket_Limitation': 'Limitado a 8 boletos por comprador. Por favor revisa los detalles de cada tipo de boleto, ya que en ocasiones éstos pueden contar con un límite distinto.',
#   'Venue_ID': 'KovZpZA6IlFA'},
#  '15v8ZboQFCZP4': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2025-03-19',
#   'Ticket_Sale_Status': 'onsale',
#   'Ticket_Min_Price': 998.0,
#   'Ticket_Max_Price': 8899.0,
#   'Ticket_Limitation': 'Limitado a 8 boletos por comprador. Por favor revisa los detalles de cada tipo de boleto, ya que en ocasiones éstos pueden contar con un límite distinto.',
#   'Venue_ID': 'KovZpZAd1IaA'},
#  '1kAZv-AIGA5jYJo': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2025-03-21',
#   'Ticket_Sale_Status': 'onsale',
#   'Ticket_Min_Price': 998.0,
#   'Ticket_Max_Price': 8899.0,
#   'Ticket_Limitation': 'Limitado a 8 boletos por comprador. Por favor revisa los detalles de cada tipo de boleto, ya que en ocasiones éstos pueden contar con un límite distinto.',
#   'Venue_ID': 'KovZpZAd1IaA'},
#  '1kAZv-AIGA5q8JQ': {'Concert_Name': 'Shakira - Las Mujeres Ya No Lloran - World Tour',
#   'Concert_Date': '2025-03-23',
#   'Ticket_Sale_Status': 'onsale',
#   'Ticket_Min_Price': 998.0,
#   'Ticket_Max_Price': 8899.0,
#   'Ticket_Limitation': 'Limitado a 8 boletos por comprador. Por favor revisa los detalles de cada tipo de boleto, ya que en ocasiones éstos pueden contar con un límite distinto.',
#   'Venue_ID': 'KovZpZAd1IaA'}}

# %%
# Create a DF for the concerts
concerts_df = pd.DataFrame.from_dict(dict_of_concerts, orient='index')

# Reset the index to make the concert IDs a regular column
concerts_df.reset_index(inplace=True)
concerts_df.rename(columns={'index': 'Event_ID'}, inplace=True)

# Display the DataFrame
concerts_df
# Out:
#             Event_ID                                     Concert_Name  \
# 0     vvG1IZbFSkKfhJ  Shakira - Las Mujeres Ya No Lloran - World Tour
# 1     vvG1IZbFTpcNCA  Shakira - Las Mujeres Ya No Lloran - World Tour
# 2   vv170ZbFGkMDd4OB  Shakira - Las Mujeres Ya No Lloran - World Tour
# 3      G5dIZbFwIrgO8  Shakira - Las Mujeres Ya No Lloran - World Tour
# 4     vvG1YZbFSrWgPY  Shakira - Las Mujeres Ya No Lloran - World Tour
# 5     vvG1VZbFU3Rv5A  Shakira - Las Mujeres Ya No Lloran - World Tour
# 6     vvG1VZbFX9ZdVo  Shakira - Las Mujeres Ya No Lloran - World Tour
# 7      G5eVZbFMbObre  Shakira - Las Mujeres Ya No Lloran - World Tour
# 8    1AvfZbFGkRnDJIs  Shakira - Las Mujeres Ya No Lloran - World Tour
# 9    1AdZZbFGkww3sSf  Shakira - Las Mujeres Ya No Lloran - World Tour
# 10   1AYZke8GkdyGvh8  Shakira - Las Mujeres Ya No Lloran - World Tour
# 11  vv177ZbFGkwEuVoY  Shakira - Las Mujeres Ya No Lloran - World Tour
# 12  vv178ZbFGkR05dgA  Shakira - Las Mujeres Ya No Lloran - World Tour
# 13     G5dVZbor9h-KC  Shakira - Las Mujeres Ya No Lloran - World Tour
# 14     G5dVZboLnUfWx  Shakira - Las Mujeres Ya No Lloran - World Tour
# 15     G5dVZbonKI-2s  Shakira - Las Mujeres Ya No Lloran - World Tour
# 16     G5dVZbonEToPC  Shakira - Las Mujeres Ya No Lloran - World Tour
# 17     15v8ZboQFCZP4  Shakira - Las Mujeres Ya No Lloran - World Tour
# 18   1kAZv-AIGA5jYJo  Shakira - Las Mujeres Ya No Lloran - World Tour
# 19   1kAZv-AIGA5q8JQ  Shakira - Las Mujeres Ya No Lloran - World Tour
#
#    Concert_Date Ticket_Sale_Status  Ticket_Min_Price  Ticket_Max_Price  \
# 0    2024-11-02          cancelled             201.5            564.75
# 1    2024-11-03          cancelled             201.5            564.75
# 2    2024-11-09          cancelled             249.5            589.50
# 3    2024-11-16          cancelled             189.5            499.50
# 4    2024-11-17          cancelled             149.5            491.50
# 5    2024-11-20          cancelled             145.5            485.50
# 6    2024-11-21          cancelled             145.5            485.50
# 7    2024-11-23          cancelled             129.5            429.50
# 8    2024-11-25          cancelled             129.5            429.50
# 9    2024-12-05          cancelled             149.5            489.50
# 10   2024-12-06          cancelled             149.5            489.50
# 11   2024-12-08          cancelled             119.5            399.50
# 12   2024-12-14          cancelled             144.5            485.00
# 13   2025-03-12             onsale             599.0           6599.00
# 14   2025-03-13             onsale             599.0           6599.00
# 15   2025-03-16             onsale             998.0           6599.00
# 16   2025-03-17             onsale             998.0           6599.00
# 17   2025-03-19             onsale             998.0           8899.00
# 18   2025-03-21             onsale             998.0           8899.00
# 19   2025-03-23             onsale             998.0           8899.00
#
#                                     Ticket_Limitation      Venue_ID
# 0   There is an overall 6 ticket limit for this ev...   KovZ917A-Tn
# 1   There is an overall 6 ticket limit for this ev...   KovZ917A-Tn
# 2   There is an overall 6 ticket limit for this ev...  KovZpZAEkn6A
# 3   There is an overall 6 ticket limit for this ev...  KovZpZAJJEdA
# 4   There is an overall 6 ticket limit for this ev...  KovZpZAJ67eA
# 5     There is a six (6) ticket limit for this event.  KovZpZAJtFaA
# 6     There is a six (6) ticket limit for this event.  KovZpZAJtFaA
# 7                                            No Limit  KovZpZA6AEIA
# 8   There is an overall 6 ticket limit for this ev...    KovZpaKuJe
# 9             There is a 6 ticket limit on this event   KovZ917AtP3
# 10            There is a 6 ticket limit on this event   KovZ917AtP3
# 11  There is an overall 6 ticket limit for this ev...    KovZpa2gne
# 12  There is an overall 6 ticket limit for this ev...    KovZpa2M7e
# 13  Limitado a 8 boletos por comprador. Por favor ...  KovZpZAEeI7A
# 14  Limitado a 8 boletos por comprador. Por favor ...  KovZpZAEeI7A
# 15  Limitado a 8 boletos por comprador. Por favor ...  KovZpZA6IlFA
# 16  Limitado a 8 boletos por comprador. Por favor ...  KovZpZA6IlFA
# 17  Limitado a 8 boletos por comprador. Por favor ...  KovZpZAd1IaA
# 18  Limitado a 8 boletos por comprador. Por favor ...  KovZpZAd1IaA
# 19  Limitado a 8 boletos por comprador. Por favor ...  KovZpZAd1IaA

# %%
# Create a list of dictionaries to store the key information about the venues
dict_of_venues = {}

# Loop throug all the concerts and extract relevant venue information
for venue in concerts:
    venue_dict = {}

    if (venue['dates']['status']['code'] != 'offsale'):
        # Use the venue ID as the index to add the venue_dict to the dict_of_venues
        venue_id = venue['_embedded']['venues'][0]['id']

        venue_name = venue['_embedded']['venues'][0]['name']
        venue_dict['Venue_Name'] = venue_name

        # Use a try-except statement for varables that aren't necessarily common to all the venues
        try:
            venue_location_lon = venue['_embedded']['venues'][0]['location']['longitude']
            venue_dict['Longitude'] = venue_location_lon
            venue_location_lat = venue['_embedded']['venues'][0]['location']['latitude']
            venue_dict['Latitude'] = venue_location_lat 
        except (KeyError):
            venue_dict['Longitude'] = 'N/A'
            venue_dict['Latitude'] = 'N/A'

        try:
            venue_country = venue['_embedded']['venues'][0]['country']['name']
            venue_dict['Country'] = venue_country
            venue_state = venue['_embedded']['venues'][0]['state']['name']
            venue_dict['State'] = venue_state
            venue_city = venue['_embedded']['venues'][0]['city']['name']
            venue_dict['City'] = venue_city
            venue_address = venue['_embedded']['venues'][0]['address']['line1']
            venue_dict['Address'] = venue_address
        except (KeyError):
            venue_dict['Country'] = 'N/A'
            venue_dict['State'] = 'N/A'
            venue_dict['City'] = 'N/A'
            venue_dict['Address'] = 'N/A'
        
        # Add the venue_dict to the dict_of_venues
        dict_of_venues[venue_id] = venue_dict

dict_of_venues
# Out:
# {'KovZ917A-Tn': {'Venue_Name': 'Acrisure Arena at Greater Palm Springs',
#   'Longitude': '-116.542747',
#   'Latitude': '33.825315',
#   'Country': 'United States Of America',
#   'State': 'California',
#   'City': 'Palm Desert',
#   'Address': '75702 Varner Rd.'},
#  'KovZpZAEkn6A': {'Venue_Name': 'Kia Forum',
#   'Longitude': '-118.341868',
#   'Latitude': '33.9583',
#   'Country': 'United States Of America',
#   'State': 'California',
#   'City': 'Inglewood',
#   'Address': '3900 W Manchester Blvd.'},
#  'KovZpZAJJEdA': {'Venue_Name': 'Frost Bank Center',
#   'Longitude': '-98.4337987',
#   'Latitude': '29.4330386',
#   'Country': 'United States Of America',
#   'State': 'Texas',
#   'City': 'San Antonio',
#   'Address': '1 Frost Bank Center Drive'},
#  'KovZpZAJ67eA': {'Venue_Name': 'American Airlines Center',
#   'Longitude': '-96.81081803',
#   'Latitude': '32.79067196',
#   'Country': 'United States Of America',
#   'State': 'Texas',
#   'City': 'Dallas',
#   'Address': '2500 Victory Avenue'},
#  'KovZpZAJtFaA': {'Venue_Name': 'Kaseya Center',
#   'Longitude': '-80.187805',
#   'Latitude': '25.781232',
#   'Country': 'United States Of America',
#   'State': 'Florida',
#   'City': 'Miami',
#   'Address': '601 Biscayne Blvd'},
#  'KovZpZA6AEIA': {'Venue_Name': 'Spectrum Center ',
#   'Longitude': '-80.839921',
#   'Latitude': '35.225222',
#   'Country': 'United States Of America',
#   'State': 'North Carolina',
#   'City': 'Charlotte',
#   'Address': '333 East Trade Street'},
#  'KovZpaKuJe': {'Venue_Name': 'Capital One Arena',
#   'Longitude': '-77.020029',
#   'Latitude': '38.897412',
#   'Country': 'United States Of America',
#   'State': 'District of Columbia',
#   'City': 'Washington',
#   'Address': '601 F Street NW'},
#  'KovZ917AtP3': {'Venue_Name': 'Barclays Center',
#   'Longitude': '-73.97519',
#   'Latitude': '40.68285',
#   'Country': 'United States Of America',
#   'State': 'New York',
#   'City': 'Brooklyn',
#   'Address': '620 Atlantic Ave'},
#  'KovZpa2gne': {'Venue_Name': 'TD Garden',
#   'Longitude': '-71.060724',
#   'Latitude': '42.365841',
#   'Country': 'United States Of America',
#   'State': 'Massachusetts',
#   'City': 'Boston',
#   'Address': '100 Legends Way'},
#  'KovZpa2M7e': {'Venue_Name': 'United Center',
#   'Longitude': '-87.67427375',
#   'Latitude': '41.88124412',
#   'Country': 'United States Of America',
#   'State': 'Illinois',
#   'City': 'Chicago',
#   'Address': '1901 W Madison'},
#  'KovZpZAEeI7A': {'Venue_Name': 'Estadio BBVA',
#   'Longitude': '-100.24442',
#   'Latitude': '25.669187',
#   'Country': 'Mexico',
#   'State': 'Nuevo León',
#   'City': 'Guadalupe',
#   'Address': 'Av. Pablo Livas No. 2011'},
#  'KovZpZA6IlFA': {'Venue_Name': 'Estadio Akron',
#   'Longitude': '-103.462611',
#   'Latitude': '20.681796',
#   'Country': 'Mexico',
#   'State': 'Jalisco',
#   'City': 'Zapopan',
#   'Address': 'Av. Vallarta y Anillo Periférico'},
#  'KovZpZAd1IaA': {'Venue_Name': 'Estadio GNP Seguros',
#   'Longitude': '-99.095618',
#   'Latitude': '19.405199',
#   'Country': 'Mexico',
#   'State': 'Ciudad de México',
#   'City': 'Cdmx',
#   'Address': 'Viaducto Piedad y Río Churubusco s/n Cd. Deportiva'}}

# %%
# Create a DF for the venues
venues_df = pd.DataFrame.from_dict(dict_of_venues, orient='index')

# Reset the index to make the concert IDs a regular column
venues_df.reset_index(inplace=True)
venues_df.rename(columns={'index': 'Venue_ID'}, inplace=True)

# Display the DataFrame
venues_df
# Out:
#         Venue_ID                              Venue_Name     Longitude  \
# 0    KovZ917A-Tn  Acrisure Arena at Greater Palm Springs   -116.542747
# 1   KovZpZAEkn6A                               Kia Forum   -118.341868
# 2   KovZpZAJJEdA                       Frost Bank Center   -98.4337987
# 3   KovZpZAJ67eA                American Airlines Center  -96.81081803
# 4   KovZpZAJtFaA                           Kaseya Center    -80.187805
# 5   KovZpZA6AEIA                        Spectrum Center     -80.839921
# 6     KovZpaKuJe                       Capital One Arena    -77.020029
# 7    KovZ917AtP3                         Barclays Center     -73.97519
# 8     KovZpa2gne                               TD Garden    -71.060724
# 9     KovZpa2M7e                           United Center  -87.67427375
# 10  KovZpZAEeI7A                            Estadio BBVA    -100.24442
# 11  KovZpZA6IlFA                           Estadio Akron   -103.462611
# 12  KovZpZAd1IaA                     Estadio GNP Seguros    -99.095618
#
#        Latitude                   Country                 State         City  \
# 0     33.825315  United States Of America            California  Palm Desert
# 1       33.9583  United States Of America            California    Inglewood
# 2    29.4330386  United States Of America                 Texas  San Antonio
# 3   32.79067196  United States Of America                 Texas       Dallas
# 4     25.781232  United States Of America               Florida        Miami
# 5     35.225222  United States Of America        North Carolina    Charlotte
# 6     38.897412  United States Of America  District of Columbia   Washington
# 7      40.68285  United States Of America              New York     Brooklyn
# 8     42.365841  United States Of America         Massachusetts       Boston
# 9   41.88124412  United States Of America              Illinois      Chicago
# 10    25.669187                    Mexico            Nuevo León    Guadalupe
# 11    20.681796                    Mexico               Jalisco      Zapopan
# 12    19.405199                    Mexico      Ciudad de México         Cdmx
#
#                                               Address
# 0                                    75702 Varner Rd.
# 1                             3900 W Manchester Blvd.
# 2                           1 Frost Bank Center Drive
# 3                                 2500 Victory Avenue
# 4                                   601 Biscayne Blvd
# 5                               333 East Trade Street
# 6                                     601 F Street NW
# 7                                    620 Atlantic Ave
# 8                                     100 Legends Way
# 9                                      1901 W Madison
# 10                           Av. Pablo Livas No. 2011
# 11                   Av. Vallarta y Anillo Periférico
# 12  Viaducto Piedad y Río Churubusco s/n Cd. Depor...

# %%
# Check the datatypes for concerts
concerts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Event_ID            20 non-null     object
#  1   Concert_Name        20 non-null     object
#  2   Concert_Date        20 non-null     object
#  3   Ticket_Sale_Status  20 non-null     object
#  4   Ticket_Min_Price    20 non-null     float64
#  5   Ticket_Max_Price    20 non-null     float64
#  6   Ticket_Limitation   20 non-null     object
#  7   Venue_ID            20 non-null     object
# dtypes: float64(2), object(6)
# memory usage: 1.4+ KB

# %%
# List of columns to convert
columns_to_convert = ['Ticket_Min_Price', 'Ticket_Max_Price']

# Apply pd.to_numeric to each specified column
for column in columns_to_convert:
    concerts_df[column] = pd.to_numeric(concerts_df[column], errors='coerce')

# Format the date column to datetime format
concerts_df["Concert_Date"] = pd.to_datetime(concerts_df["Concert_Date"])
concerts_df
# Out:
#             Event_ID                                     Concert_Name  \
# 0     vvG1IZbFSkKfhJ  Shakira - Las Mujeres Ya No Lloran - World Tour
# 1     vvG1IZbFTpcNCA  Shakira - Las Mujeres Ya No Lloran - World Tour
# 2   vv170ZbFGkMDd4OB  Shakira - Las Mujeres Ya No Lloran - World Tour
# 3      G5dIZbFwIrgO8  Shakira - Las Mujeres Ya No Lloran - World Tour
# 4     vvG1YZbFSrWgPY  Shakira - Las Mujeres Ya No Lloran - World Tour
# 5     vvG1VZbFU3Rv5A  Shakira - Las Mujeres Ya No Lloran - World Tour
# 6     vvG1VZbFX9ZdVo  Shakira - Las Mujeres Ya No Lloran - World Tour
# 7      G5eVZbFMbObre  Shakira - Las Mujeres Ya No Lloran - World Tour
# 8    1AvfZbFGkRnDJIs  Shakira - Las Mujeres Ya No Lloran - World Tour
# 9    1AdZZbFGkww3sSf  Shakira - Las Mujeres Ya No Lloran - World Tour
# 10   1AYZke8GkdyGvh8  Shakira - Las Mujeres Ya No Lloran - World Tour
# 11  vv177ZbFGkwEuVoY  Shakira - Las Mujeres Ya No Lloran - World Tour
# 12  vv178ZbFGkR05dgA  Shakira - Las Mujeres Ya No Lloran - World Tour
# 13     G5dVZbor9h-KC  Shakira - Las Mujeres Ya No Lloran - World Tour
# 14     G5dVZboLnUfWx  Shakira - Las Mujeres Ya No Lloran - World Tour
# 15     G5dVZbonKI-2s  Shakira - Las Mujeres Ya No Lloran - World Tour
# 16     G5dVZbonEToPC  Shakira - Las Mujeres Ya No Lloran - World Tour
# 17     15v8ZboQFCZP4  Shakira - Las Mujeres Ya No Lloran - World Tour
# 18   1kAZv-AIGA5jYJo  Shakira - Las Mujeres Ya No Lloran - World Tour
# 19   1kAZv-AIGA5q8JQ  Shakira - Las Mujeres Ya No Lloran - World Tour
#
#    Concert_Date Ticket_Sale_Status  Ticket_Min_Price  Ticket_Max_Price  \
# 0    2024-11-02          cancelled             201.5            564.75
# 1    2024-11-03          cancelled             201.5            564.75
# 2    2024-11-09          cancelled             249.5            589.50
# 3    2024-11-16          cancelled             189.5            499.50
# 4    2024-11-17          cancelled             149.5            491.50
# 5    2024-11-20          cancelled             145.5            485.50
# 6    2024-11-21          cancelled             145.5            485.50
# 7    2024-11-23          cancelled             129.5            429.50
# 8    2024-11-25          cancelled             129.5            429.50
# 9    2024-12-05          cancelled             149.5            489.50
# 10   2024-12-06          cancelled             149.5            489.50
# 11   2024-12-08          cancelled             119.5            399.50
# 12   2024-12-14          cancelled             144.5            485.00
# 13   2025-03-12             onsale             599.0           6599.00
# 14   2025-03-13             onsale             599.0           6599.00
# 15   2025-03-16             onsale             998.0           6599.00
# 16   2025-03-17             onsale             998.0           6599.00
# 17   2025-03-19             onsale             998.0           8899.00
# 18   2025-03-21             onsale             998.0           8899.00
# 19   2025-03-23             onsale             998.0           8899.00
#
#                                     Ticket_Limitation      Venue_ID
# 0   There is an overall 6 ticket limit for this ev...   KovZ917A-Tn
# 1   There is an overall 6 ticket limit for this ev...   KovZ917A-Tn
# 2   There is an overall 6 ticket limit for this ev...  KovZpZAEkn6A
# 3   There is an overall 6 ticket limit for this ev...  KovZpZAJJEdA
# 4   There is an overall 6 ticket limit for this ev...  KovZpZAJ67eA
# 5     There is a six (6) ticket limit for this event.  KovZpZAJtFaA
# 6     There is a six (6) ticket limit for this event.  KovZpZAJtFaA
# 7                                            No Limit  KovZpZA6AEIA
# 8   There is an overall 6 ticket limit for this ev...    KovZpaKuJe
# 9             There is a 6 ticket limit on this event   KovZ917AtP3
# 10            There is a 6 ticket limit on this event   KovZ917AtP3
# 11  There is an overall 6 ticket limit for this ev...    KovZpa2gne
# 12  There is an overall 6 ticket limit for this ev...    KovZpa2M7e
# 13  Limitado a 8 boletos por comprador. Por favor ...  KovZpZAEeI7A
# 14  Limitado a 8 boletos por comprador. Por favor ...  KovZpZAEeI7A
# 15  Limitado a 8 boletos por comprador. Por favor ...  KovZpZA6IlFA
# 16  Limitado a 8 boletos por comprador. Por favor ...  KovZpZA6IlFA
# 17  Limitado a 8 boletos por comprador. Por favor ...  KovZpZAd1IaA
# 18  Limitado a 8 boletos por comprador. Por favor ...  KovZpZAd1IaA
# 19  Limitado a 8 boletos por comprador. Por favor ...  KovZpZAd1IaA

# %%
# Recheck the datatypes for concerts
concerts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Event_ID            20 non-null     object
#  1   Concert_Name        20 non-null     object
#  2   Concert_Date        20 non-null     datetime64[ns]
#  3   Ticket_Sale_Status  20 non-null     object
#  4   Ticket_Min_Price    20 non-null     float64
#  5   Ticket_Max_Price    20 non-null     float64
#  6   Ticket_Limitation   20 non-null     object
#  7   Venue_ID            20 non-null     object
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 1.4+ KB

# %%
# Check the datatypes for venues
venues_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Venue_ID    13 non-null     object
#  1   Venue_Name  13 non-null     object
#  2   Longitude   13 non-null     object
#  3   Latitude    13 non-null     object
#  4   Country     13 non-null     object
#  5   State       13 non-null     object
#  6   City        13 non-null     object
#  7   Address     13 non-null     object
# dtypes: object(8)
# memory usage: 960.0+ bytes

# %%
# List of columns to convert
columns_to_convert = ['Longitude', 'Latitude']

# Apply pd.to_numeric to each specified column
for column in columns_to_convert:
    venues_df[column] = pd.to_numeric(venues_df[column], errors='coerce')

# %%
# Recheck the datatypes for venues
venues_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Venue_ID    13 non-null     object
#  1   Venue_Name  13 non-null     object
#  2   Longitude   13 non-null     float64
#  3   Latitude    13 non-null     float64
#  4   Country     13 non-null     object
#  5   State       13 non-null     object
#  6   City        13 non-null     object
#  7   Address     13 non-null     object
# dtypes: float64(2), object(6)
# memory usage: 960.0+ bytes

# %%
# Create a new df with lodging information
lodging_info = pd.merge(concerts_df, venues_df, on='Venue_ID', how='left')

lodging_info = lodging_info.drop(columns=['Event_ID', 'Concert_Name', 'Ticket_Sale_Status', 'Ticket_Min_Price',
                                          'Ticket_Max_Price', 'Ticket_Limitation', 'Venue_Name', 'Longitude',
                                          'Latitude', 'Address' ])

lodging_info['CheckIn_Date'] = lodging_info['Concert_Date'] - timedelta(days=1)
lodging_info['CheckOut_Date'] = lodging_info['Concert_Date'] + timedelta(days=1)

lodging_info
# Out:
#    Concert_Date      Venue_ID                   Country                 State  \
# 0    2024-11-02   KovZ917A-Tn  United States Of America            California
# 1    2024-11-03   KovZ917A-Tn  United States Of America            California
# 2    2024-11-09  KovZpZAEkn6A  United States Of America            California
# 3    2024-11-16  KovZpZAJJEdA  United States Of America                 Texas
# 4    2024-11-17  KovZpZAJ67eA  United States Of America                 Texas
# 5    2024-11-20  KovZpZAJtFaA  United States Of America               Florida
# 6    2024-11-21  KovZpZAJtFaA  United States Of America               Florida
# 7    2024-11-23  KovZpZA6AEIA  United States Of America        North Carolina
# 8    2024-11-25    KovZpaKuJe  United States Of America  District of Columbia
# 9    2024-12-05   KovZ917AtP3  United States Of America              New York
# 10   2024-12-06   KovZ917AtP3  United States Of America              New York
# 11   2024-12-08    KovZpa2gne  United States Of America         Massachusetts
# 12   2024-12-14    KovZpa2M7e  United States Of America              Illinois
# 13   2025-03-12  KovZpZAEeI7A                    Mexico            Nuevo León
# 14   2025-03-13  KovZpZAEeI7A                    Mexico            Nuevo León
# 15   2025-03-16  KovZpZA6IlFA                    Mexico               Jalisco
# 16   2025-03-17  KovZpZA6IlFA                    Mexico               Jalisco
# 17   2025-03-19  KovZpZAd1IaA                    Mexico      Ciudad de México
# 18   2025-03-21  KovZpZAd1IaA                    Mexico      Ciudad de México
# 19   2025-03-23  KovZpZAd1IaA                    Mexico      Ciudad de México
#
#            City CheckIn_Date CheckOut_Date
# 0   Palm Desert   2024-11-01    2024-11-03
# 1   Palm Desert   2024-11-02    2024-11-04
# 2     Inglewood   2024-11-08    2024-11-10
# 3   San Antonio   2024-11-15    2024-11-17
# 4        Dallas   2024-11-16    2024-11-18
# 5         Miami   2024-11-19    2024-11-21
# 6         Miami   2024-11-20    2024-11-22
# 7     Charlotte   2024-11-22    2024-11-24
# 8    Washington   2024-11-24    2024-11-26
# 9      Brooklyn   2024-12-04    2024-12-06
# 10     Brooklyn   2024-12-05    2024-12-07
# 11       Boston   2024-12-07    2024-12-09
# 12      Chicago   2024-12-13    2024-12-15
# 13    Guadalupe   2025-03-11    2025-03-13
# 14    Guadalupe   2025-03-12    2025-03-14
# 15      Zapopan   2025-03-15    2025-03-17
# 16      Zapopan   2025-03-16    2025-03-18
# 17         Cdmx   2025-03-18    2025-03-20
# 18         Cdmx   2025-03-20    2025-03-22
# 19         Cdmx   2025-03-22    2025-03-24

# %%
# Write CSV files
concerts_df.to_csv("../Resources/concerts_info.csv", index=False, header=True)
venues_df.to_csv("../Resources/venues_info.csv", index=False, header=True)
lodging_info.to_csv("../Resources/lodging_info.csv", index=False, header=True)
